# %% [markdown]
# # ETL & Visualization Project

# %% [markdown]
# ## UV Exposure & Melanoma Rates Correlation in United States

# %% [markdown]
# ### Extract: UV Exposure and Melanoma Data (csv)

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# from scipy.stats import linregress
# from scipy import stats
# import pingouin as pg # Install pingouin stats package (pip install pingouin)
# import seaborn as sns # Install seaborn data visualization library (pip install seaborn)
# from scipy.stats import pearsonr

yr_list= [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
       2014, 2015]

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load
CDI_data_to_load = "CDI_data.csv"

# Read the Population Health Data
CDI_data_pd = pd.read_csv(CDI_data_to_load)

# Display the data table for preview
CDI_data_pd
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0            2013     2013           CA            California      YRBSS
# 1            2013     2013           CO              Colorado      YRBSS
# 2            2013     2013           CT           Connecticut      YRBSS
# 3            2013     2013           DC  District of Columbia      YRBSS
# 4            2013     2013           DE              Delaware      YRBSS
# ...           ...      ...          ...                   ...        ...
# 237956       2012     2012           WI             Wisconsin      BRFSS
# 237957       2012     2012           WY               Wyoming      BRFSS
# 237958       2012     2012           GU                  Guam      BRFSS
# 237959       2012     2012           PR           Puerto Rico      BRFSS
# 237960       2012     2012           VI        Virgin Islands      BRFSS
#
#                Topic                                           Question  \
# 0            Alcohol                            Alcohol use among youth
# 1            Alcohol                            Alcohol use among youth
# 2            Alcohol                            Alcohol use among youth
# 3            Alcohol                            Alcohol use among youth
# 4            Alcohol                            Alcohol use among youth
# ...              ...                                                ...
# 237956  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237957  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237958  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237959  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237960  Older Adults  Proportion of older adults aged 50-64 years wh...
#
#        Response DataValueUnit DataValueTypeID  ... TopicID QuestionID  \
# 0           NaN             %         CrdPrev  ...     ALC     ALC1_1
# 1           NaN             %         CrdPrev  ...     ALC     ALC1_1
# 2           NaN             %         CrdPrev  ...     ALC     ALC1_1
# 3           NaN             %         CrdPrev  ...     ALC     ALC1_1
# 4           NaN             %         CrdPrev  ...     ALC     ALC1_1
# ...         ...           ...             ...  ...     ...        ...
# 237956      NaN             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237957      NaN             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237958      NaN             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237959      NaN             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237960      NaN             %      AgeAdjPrev  ...     OLD     OLD3_2
#
#         ResponseID LocationID StratificationCategoryID1  StratificationID1  \
# 0              NaN          6                   OVERALL                OVR
# 1              NaN          8                   OVERALL                OVR
# 2              NaN          9                   OVERALL                OVR
# 3              NaN         11                   OVERALL                OVR
# 4              NaN         10                   OVERALL                OVR
# ...            ...        ...                       ...                ...
# 237956         NaN         55                      RACE                MRC
# 237957         NaN         56                      RACE                MRC
# 237958         NaN         66                      RACE                MRC
# 237959         NaN         72                      RACE                MRC
# 237960         NaN         78                      RACE                MRC
#
#         StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                             NaN               NaN                       NaN
# 1                             NaN               NaN                       NaN
# 2                             NaN               NaN                       NaN
# 3                             NaN               NaN                       NaN
# 4                             NaN               NaN                       NaN
# ...                           ...               ...                       ...
# 237956                        NaN               NaN                       NaN
# 237957                        NaN               NaN                       NaN
# 237958                        NaN               NaN                       NaN
# 237959                        NaN               NaN                       NaN
# 237960                        NaN               NaN                       NaN
#
#        StratificationID3
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 237956               NaN
# 237957               NaN
# 237958               NaN
# 237959               NaN
# 237960               NaN
#
# [237961 rows x 34 columns]

# %%
# Extracting cancer data

topic_sorted_df = CDI_data_pd.groupby('Topic')
topic_sorted_df
cancer_df = topic_sorted_df.get_group('Cancer') 
cancer_df
cancer_df = cancer_df.sort_values('LocationDesc')
cancer_df[[]]

new_cancer_df = cancer_df[['LocationAbbr','LocationDesc','Topic',
                                        'Question','DataValueType','DataValue']].copy()
new_cancer_df
# Out:
#       LocationAbbr LocationDesc   Topic  \
# 49892           AL      Alabama  Cancer
# 50608           AL      Alabama  Cancer
# 50607           AL      Alabama  Cancer
# 50606           AL      Alabama  Cancer
# 48310           AL      Alabama  Cancer
# ...            ...          ...     ...
# 48305           WY      Wyoming  Cancer
# 48304           WY      Wyoming  Cancer
# 48150           WY      Wyoming  Cancer
# 49865           WY      Wyoming  Cancer
# 53427           WY      Wyoming  Cancer
#
#                                                 Question  \
# 49892  Recent Papanicolaou smear use among women aged...
# 50608  Fecal occult blood test, sigmoidoscopy, or col...
# 50607  Fecal occult blood test, sigmoidoscopy, or col...
# 50606  Fecal occult blood test, sigmoidoscopy, or col...
# 48310                  Cancer of the prostate, mortality
# ...                                                  ...
# 48305         Invasive cancer of the prostate, incidence
# 48304         Invasive cancer of the prostate, incidence
# 48150   Cancer of the oral cavity and pharynx, mortality
# 49865  Papanicolaou smear use among adult women aged ...
# 53427                                Melanoma, mortality
#
#                           DataValueType DataValue
# 49892                  Crude Prevalence       NaN
# 50608                  Crude Prevalence      61.8
# 50607           Age-adjusted Prevalence      62.6
# 50606                  Crude Prevalence        64
# 48310  Average Annual Age-adjusted Rate      26.4
# ...                                 ...       ...
# 48305         Average Annual Crude Rate     138.4
# 48304  Average Annual Age-adjusted Rate     127.1
# 48150             Average Annual Number        17
# 49865                  Crude Prevalence       NaN
# 53427             Average Annual Number        18
#
# [7001 rows x 6 columns]

# %%
incidence_df = new_cancer_df.loc[new_cancer_df['Question'] == 'Invasive melanoma, incidence']
incidence_df

incidence_df = incidence_df.loc[incidence_df['DataValueType'] == 'Average Annual Number']
incidence_df.head()
# Out:
#       LocationAbbr LocationDesc   Topic                      Question  \
# 53122           AL      Alabama  Cancer  Invasive melanoma, incidence
# 53119           AK       Alaska  Cancer  Invasive melanoma, incidence
# 53128           AZ      Arizona  Cancer  Invasive melanoma, incidence
# 53125           AR     Arkansas  Cancer  Invasive melanoma, incidence
# 53131           CA   California  Cancer  Invasive melanoma, incidence
#
#                DataValueType DataValue
# 53122  Average Annual Number      1128
# 53119  Average Annual Number        81
# 53128  Average Annual Number      1135
# 53125  Average Annual Number       534
# 53131  Average Annual Number      7740

# %%
mortality_df = new_cancer_df.loc[new_cancer_df['Question'] == 'Melanoma, mortality']
mortality_df

mortality_df = mortality_df.loc[mortality_df['DataValueType'] == 'Average Annual Number']
mortality_df.head()
# Out:
#       LocationAbbr LocationDesc   Topic             Question  \
# 53280           AL      Alabama  Cancer  Melanoma, mortality
# 53277           AK       Alaska  Cancer  Melanoma, mortality
# 53286           AZ      Arizona  Cancer  Melanoma, mortality
# 53283           AR     Arkansas  Cancer  Melanoma, mortality
# 53289           CA   California  Cancer  Melanoma, mortality
#
#                DataValueType DataValue
# 53280  Average Annual Number       151
# 53277  Average Annual Number        12
# 53286  Average Annual Number       203
# 53283  Average Annual Number        93
# 53289  Average Annual Number       943

# %%
# 2nd File to Load
UV_data_to_load = "UV_data.csv"

# Read the Population Health Data
UV_data_df = pd.read_csv(UV_data_to_load)

# # Display the data table for preview
UV_data_df = UV_data_df.groupby("STATENAME", as_index=False)["UV_ Wh/m²"].mean()
UV_data_df.tail()
# Out:
#         STATENAME    UV_ Wh/m²
# 44       Virginia  4181.985075
# 45     Washington  3594.102564
# 46  West Virginia  3892.363636
# 47      Wisconsin  3810.708333
# 48        Wyoming  4350.521739

# %% [markdown]
# ### Load: Database (MongoDB)

# %%
# Dependencies
import pymongo
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %% [markdown]
# #### Upload Clean Data to Database

# %% [markdown]
# #### 1. Melanoma Incidence Data

# %%
# Define database and collection
db = client.uv_melanoma_db
collection = db.melanoma_incidence

# %%
# Convert the data frame of melanoma incidence data to dictionary
incidence_dict = incidence_df.to_dict("records")
incidence_dict
# Out:
# [{'LocationAbbr': 'AL',
#   'LocationDesc': 'Alabama',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1128'},
#  {'LocationAbbr': 'AK',
#   'LocationDesc': 'Alaska',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '81'},
#  {'LocationAbbr': 'AZ',
#   'LocationDesc': 'Arizona',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1135'},
#  {'LocationAbbr': 'AR',
#   'LocationDesc': 'Arkansas',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '534'},
#  {'LocationAbbr': 'CA',
#   'LocationDesc': 'California',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '7740'},
#  {'LocationAbbr': 'CO',
#   'LocationDesc': 'Colorado',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1113'},
#  {'LocationAbbr': 'CT',
#   'LocationDesc': 'Connecticut',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '902'},
#  {'LocationAbbr': 'DE',
#   'LocationDesc': 'Delaware',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '293'},
#  {'LocationAbbr': 'DC',
#   'LocationDesc': 'District of Columbia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '49'},
#  {'LocationAbbr': 'FL',
#   'LocationDesc': 'Florida',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '4692'},
#  {'LocationAbbr': 'GA',
#   'LocationDesc': 'Georgia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2194'},
#  {'LocationAbbr': 'HI',
#   'LocationDesc': 'Hawaii',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '316'},
#  {'LocationAbbr': 'ID',
#   'LocationDesc': 'Idaho',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '405'},
#  {'LocationAbbr': 'IL',
#   'LocationDesc': 'Illinois',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2399'},
#  {'LocationAbbr': 'IN',
#   'LocationDesc': 'Indiana',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1223'},
#  {'LocationAbbr': 'IA',
#   'LocationDesc': 'Iowa',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '798'},
#  {'LocationAbbr': 'KS',
#   'LocationDesc': 'Kansas',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '712'},
#  {'LocationAbbr': 'KY',
#   'LocationDesc': 'Kentucky',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1130'},
#  {'LocationAbbr': 'LA',
#   'LocationDesc': 'Louisiana',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '714'},
#  {'LocationAbbr': 'ME',
#   'LocationDesc': 'Maine',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '370'},
#  {'LocationAbbr': 'MD',
#   'LocationDesc': 'Maryland',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1272'},
#  {'LocationAbbr': 'MA',
#   'LocationDesc': 'Massachusetts',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1590'},
#  {'LocationAbbr': 'MI',
#   'LocationDesc': 'Michigan',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2053'},
#  {'LocationAbbr': 'MN',
#   'LocationDesc': 'Minnesota',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1530'},
#  {'LocationAbbr': 'MS',
#   'LocationDesc': 'Mississippi',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '538'},
#  {'LocationAbbr': 'MO',
#   'LocationDesc': 'Missouri',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1177'},
#  {'LocationAbbr': 'MT',
#   'LocationDesc': 'Montana',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '268'},
#  {'LocationAbbr': 'NE',
#   'LocationDesc': 'Nebraska',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '356'},
#  {'LocationAbbr': 'NV',
#   'LocationDesc': 'Nevada',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': nan},
#  {'LocationAbbr': 'NH',
#   'LocationDesc': 'New Hampshire',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '400'},
#  {'LocationAbbr': 'NJ',
#   'LocationDesc': 'New Jersey',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2093'},
#  {'LocationAbbr': 'NM',
#   'LocationDesc': 'New Mexico',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '406'},
#  {'LocationAbbr': 'NY',
#   'LocationDesc': 'New York',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '3717'},
#  {'LocationAbbr': 'NC',
#   'LocationDesc': 'North Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2302'},
#  {'LocationAbbr': 'ND',
#   'LocationDesc': 'North Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '158'},
#  {'LocationAbbr': 'OH',
#   'LocationDesc': 'Ohio',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2491'},
#  {'LocationAbbr': 'OK',
#   'LocationDesc': 'Oklahoma',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '654'},
#  {'LocationAbbr': 'OR',
#   'LocationDesc': 'Oregon',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1140'},
#  {'LocationAbbr': 'PA',
#   'LocationDesc': 'Pennsylvania',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '3045'},
#  {'LocationAbbr': 'RI',
#   'LocationDesc': 'Rhode Island',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '252'},
#  {'LocationAbbr': 'SC',
#   'LocationDesc': 'South Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1144'},
#  {'LocationAbbr': 'SD',
#   'LocationDesc': 'South Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '167'},
#  {'LocationAbbr': 'TN',
#   'LocationDesc': 'Tennessee',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1431'},
#  {'LocationAbbr': 'TX',
#   'LocationDesc': 'Texas',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '3025'},
#  {'LocationAbbr': 'US',
#   'LocationDesc': 'United States',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '65719'},
#  {'LocationAbbr': 'UT',
#   'LocationDesc': 'Utah',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '742'},
#  {'LocationAbbr': 'VT',
#   'LocationDesc': 'Vermont',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '215'},
#  {'LocationAbbr': 'VA',
#   'LocationDesc': 'Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1535'},
#  {'LocationAbbr': 'WA',
#   'LocationDesc': 'Washington',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1821'},
#  {'LocationAbbr': 'WV',
#   'LocationDesc': 'West Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '464'},
#  {'LocationAbbr': 'WI',
#   'LocationDesc': 'Wisconsin',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1284'},
#  {'LocationAbbr': 'WY',
#   'LocationDesc': 'Wyoming',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '135'}]

# %%
# Upload melanoma incidence data to MongoDB
for incidence_data in range(len(incidence_dict)):
    collection.insert_one(incidence_dict[incidence_data])

# %%
# Display the MongoDB records created above
melanoma_incidence_records = db.melanoma_incidence.find()
for melanoma_incidence_record in melanoma_incidence_records:
    print(melanoma_incidence_record)
# Out:
# {'_id': ObjectId('5e810f68f0d19231df806547'), 'LocationAbbr': 'AL', 'LocationDesc': 'Alabama', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1128'}
# {'_id': ObjectId('5e810f68f0d19231df806548'), 'LocationAbbr': 'AK', 'LocationDesc': 'Alaska', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '81'}
# {'_id': ObjectId('5e810f68f0d19231df806549'), 'LocationAbbr': 'AZ', 'LocationDesc': 'Arizona', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1135'}
# {'_id': ObjectId('5e810f68f0d19231df80654a'), 'LocationAbbr': 'AR', 'LocationDesc': 'Arkansas', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '534'}
# {'_id': ObjectId('5e810f68f0d19231df80654b'), 'LocationAbbr': 'CA', 'LocationDesc': 'California', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '7740'}
# {'_id': ObjectId('5e810f68f0d19231df80654c'), 'LocationAbbr': 'CO', 'LocationDesc': 'Colorado', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1113'}
# {'_id': ObjectId('5e810f68f0d19231df80654d'), 'LocationAbbr': 'CT', 'LocationDesc': 'Connecticut', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '902'}
# {'_id': ObjectId('5e810f68f0d19231df80654e'), 'LocationAbbr': 'DE', 'LocationDesc': 'Delaware', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '293'}
# {'_id': ObjectId('5e810f68f0d19231df80654f'), 'LocationAbbr': 'DC', 'LocationDesc': 'District of Columbia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '49'}
# {'_id': ObjectId('5e810f68f0d19231df806550'), 'LocationAbbr': 'FL', 'LocationDesc': 'Florida', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '4692'}
# {'_id': ObjectId('5e810f68f0d19231df806551'), 'LocationAbbr': 'GA', 'LocationDesc': 'Georgia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2194'}
# {'_id': ObjectId('5e810f68f0d19231df806552'), 'LocationAbbr': 'HI', 'LocationDesc': 'Hawaii', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '316'}
# {'_id': ObjectId('5e810f68f0d19231df806553'), 'LocationAbbr': 'ID', 'LocationDesc': 'Idaho', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '405'}
# {'_id': ObjectId('5e810f68f0d19231df806554'), 'LocationAbbr': 'IL', 'LocationDesc': 'Illinois', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2399'}
# {'_id': ObjectId('5e810f68f0d19231df806555'), 'LocationAbbr': 'IN', 'LocationDesc': 'Indiana', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1223'}
# {'_id': ObjectId('5e810f68f0d19231df806556'), 'LocationAbbr': 'IA', 'LocationDesc': 'Iowa', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '798'}
# {'_id': ObjectId('5e810f68f0d19231df806557'), 'LocationAbbr': 'KS', 'LocationDesc': 'Kansas', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '712'}
# {'_id': ObjectId('5e810f68f0d19231df806558'), 'LocationAbbr': 'KY', 'LocationDesc': 'Kentucky', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1130'}
# {'_id': ObjectId('5e810f68f0d19231df806559'), 'LocationAbbr': 'LA', 'LocationDesc': 'Louisiana', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '714'}
# {'_id': ObjectId('5e810f68f0d19231df80655a'), 'LocationAbbr': 'ME', 'LocationDesc': 'Maine', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '370'}
# {'_id': ObjectId('5e810f68f0d19231df80655b'), 'LocationAbbr': 'MD', 'LocationDesc': 'Maryland', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1272'}
# {'_id': ObjectId('5e810f68f0d19231df80655c'), 'LocationAbbr': 'MA', 'LocationDesc': 'Massachusetts', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1590'}
# {'_id': ObjectId('5e810f68f0d19231df80655d'), 'LocationAbbr': 'MI', 'LocationDesc': 'Michigan', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2053'}
# {'_id': ObjectId('5e810f68f0d19231df80655e'), 'LocationAbbr': 'MN', 'LocationDesc': 'Minnesota', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1530'}
# {'_id': ObjectId('5e810f68f0d19231df80655f'), 'LocationAbbr': 'MS', 'LocationDesc': 'Mississippi', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '538'}
# {'_id': ObjectId('5e810f68f0d19231df806560'), 'LocationAbbr': 'MO', 'LocationDesc': 'Missouri', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1177'}
# {'_id': ObjectId('5e810f68f0d19231df806561'), 'LocationAbbr': 'MT', 'LocationDesc': 'Montana', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '268'}
# {'_id': ObjectId('5e810f68f0d19231df806562'), 'LocationAbbr': 'NE', 'LocationDesc': 'Nebraska', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '356'}
# {'_id': ObjectId('5e810f68f0d19231df806563'), 'LocationAbbr': 'NV', 'LocationDesc': 'Nevada', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': nan}
# {'_id': ObjectId('5e810f68f0d19231df806564'), 'LocationAbbr': 'NH', 'LocationDesc': 'New Hampshire', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '400'}
# {'_id': ObjectId('5e810f68f0d19231df806565'), 'LocationAbbr': 'NJ', 'LocationDesc': 'New Jersey', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2093'}
# {'_id': ObjectId('5e810f68f0d19231df806566'), 'LocationAbbr': 'NM', 'LocationDesc': 'New Mexico', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '406'}
# {'_id': ObjectId('5e810f68f0d19231df806567'), 'LocationAbbr': 'NY', 'LocationDesc': 'New York', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '3717'}
# {'_id': ObjectId('5e810f68f0d19231df806568'), 'LocationAbbr': 'NC', 'LocationDesc': 'North Carolina', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2302'}
# {'_id': ObjectId('5e810f68f0d19231df806569'), 'LocationAbbr': 'ND', 'LocationDesc': 'North Dakota', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '158'}
# {'_id': ObjectId('5e810f68f0d19231df80656a'), 'LocationAbbr': 'OH', 'LocationDesc': 'Ohio', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2491'}
# {'_id': ObjectId('5e810f68f0d19231df80656b'), 'LocationAbbr': 'OK', 'LocationDesc': 'Oklahoma', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '654'}
# {'_id': ObjectId('5e810f68f0d19231df80656c'), 'LocationAbbr': 'OR', 'LocationDesc': 'Oregon', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1140'}
# {'_id': ObjectId('5e810f68f0d19231df80656d'), 'LocationAbbr': 'PA', 'LocationDesc': 'Pennsylvania', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '3045'}
# {'_id': ObjectId('5e810f68f0d19231df80656e'), 'LocationAbbr': 'RI', 'LocationDesc': 'Rhode Island', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '252'}
# {'_id': ObjectId('5e810f68f0d19231df80656f'), 'LocationAbbr': 'SC', 'LocationDesc': 'South Carolina', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1144'}
# {'_id': ObjectId('5e810f68f0d19231df806570'), 'LocationAbbr': 'SD', 'LocationDesc': 'South Dakota', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '167'}
# {'_id': ObjectId('5e810f68f0d19231df806571'), 'LocationAbbr': 'TN', 'LocationDesc': 'Tennessee', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1431'}
# {'_id': ObjectId('5e810f68f0d19231df806572'), 'LocationAbbr': 'TX', 'LocationDesc': 'Texas', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '3025'}
# {'_id': ObjectId('5e810f68f0d19231df806573'), 'LocationAbbr': 'US', 'LocationDesc': 'United States', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '65719'}
# {'_id': ObjectId('5e810f68f0d19231df806574'), 'LocationAbbr': 'UT', 'LocationDesc': 'Utah', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '742'}
# {'_id': ObjectId('5e810f68f0d19231df806575'), 'LocationAbbr': 'VT', 'LocationDesc': 'Vermont', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '215'}
# {'_id': ObjectId('5e810f68f0d19231df806576'), 'LocationAbbr': 'VA', 'LocationDesc': 'Virginia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1535'}
# {'_id': ObjectId('5e810f68f0d19231df806577'), 'LocationAbbr': 'WA', 'LocationDesc': 'Washington', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1821'}
# {'_id': ObjectId('5e810f68f0d19231df806578'), 'LocationAbbr': 'WV', 'LocationDesc': 'West Virginia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '464'}
# {'_id': ObjectId('5e810f68f0d19231df806579'), 'LocationAbbr': 'WI', 'LocationDesc': 'Wisconsin', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1284'}
# {'_id': ObjectId('5e810f68f0d19231df80657a'), 'LocationAbbr': 'WY', 'LocationDesc': 'Wyoming', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '135'}

# %% [markdown]
# #### 2. Melanoma Mortality Data

# %%
# Define database and collection
db = client.uv_melanoma_db
collection = db.melanoma_mortality

# %%
# Convert the data frame of melanoma mortality data to dictionary
mortality_dict = mortality_df.to_dict("records")
mortality_dict
# Out:
# [{'LocationAbbr': 'AL',
#   'LocationDesc': 'Alabama',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '151'},
#  {'LocationAbbr': 'AK',
#   'LocationDesc': 'Alaska',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '12'},
#  {'LocationAbbr': 'AZ',
#   'LocationDesc': 'Arizona',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '203'},
#  {'LocationAbbr': 'AR',
#   'LocationDesc': 'Arkansas',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '93'},
#  {'LocationAbbr': 'CA',
#   'LocationDesc': 'California',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '943'},
#  {'LocationAbbr': 'CO',
#   'LocationDesc': 'Colorado',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '161'},
#  {'LocationAbbr': 'CT',
#   'LocationDesc': 'Connecticut',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '106'},
#  {'LocationAbbr': 'DE',
#   'LocationDesc': 'Delaware',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '29'},
#  {'LocationAbbr': 'DC',
#   'LocationDesc': 'District of Columbia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '7'},
#  {'LocationAbbr': 'FL',
#   'LocationDesc': 'Florida',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '728'},
#  {'LocationAbbr': 'GA',
#   'LocationDesc': 'Georgia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '217'},
#  {'LocationAbbr': 'HI',
#   'LocationDesc': 'Hawaii',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '24'},
#  {'LocationAbbr': 'ID',
#   'LocationDesc': 'Idaho',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '55'},
#  {'LocationAbbr': 'IL',
#   'LocationDesc': 'Illinois',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '328'},
#  {'LocationAbbr': 'IN',
#   'LocationDesc': 'Indiana',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '215'},
#  {'LocationAbbr': 'IA',
#   'LocationDesc': 'Iowa',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '106'},
#  {'LocationAbbr': 'KS',
#   'LocationDesc': 'Kansas',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '93'},
#  {'LocationAbbr': 'KY',
#   'LocationDesc': 'Kentucky',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '151'},
#  {'LocationAbbr': 'LA',
#   'LocationDesc': 'Louisiana',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '105'},
#  {'LocationAbbr': 'ME',
#   'LocationDesc': 'Maine',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '51'},
#  {'LocationAbbr': 'MD',
#   'LocationDesc': 'Maryland',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '160'},
#  {'LocationAbbr': 'MA',
#   'LocationDesc': 'Massachusetts',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '219'},
#  {'LocationAbbr': 'MI',
#   'LocationDesc': 'Michigan',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '275'},
#  {'LocationAbbr': 'MN',
#   'LocationDesc': 'Minnesota',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '144'},
#  {'LocationAbbr': 'MS',
#   'LocationDesc': 'Mississippi',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '71'},
#  {'LocationAbbr': 'MO',
#   'LocationDesc': 'Missouri',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '208'},
#  {'LocationAbbr': 'MT',
#   'LocationDesc': 'Montana',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '36'},
#  {'LocationAbbr': 'NE',
#   'LocationDesc': 'Nebraska',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '63'},
#  {'LocationAbbr': 'NV',
#   'LocationDesc': 'Nevada',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '80'},
#  {'LocationAbbr': 'NH',
#   'LocationDesc': 'New Hampshire',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '42'},
#  {'LocationAbbr': 'NJ',
#   'LocationDesc': 'New Jersey',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '245'},
#  {'LocationAbbr': 'NM',
#   'LocationDesc': 'New Mexico',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '60'},
#  {'LocationAbbr': 'NY',
#   'LocationDesc': 'New York',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '484'},
#  {'LocationAbbr': 'NC',
#   'LocationDesc': 'North Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '296'},
#  {'LocationAbbr': 'ND',
#   'LocationDesc': 'North Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '17'},
#  {'LocationAbbr': 'OH',
#   'LocationDesc': 'Ohio',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '391'},
#  {'LocationAbbr': 'OK',
#   'LocationDesc': 'Oklahoma',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '130'},
#  {'LocationAbbr': 'OR',
#   'LocationDesc': 'Oregon',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '147'},
#  {'LocationAbbr': 'PA',
#   'LocationDesc': 'Pennsylvania',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '459'},
#  {'LocationAbbr': 'RI',
#   'LocationDesc': 'Rhode Island',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '32'},
#  {'LocationAbbr': 'SC',
#   'LocationDesc': 'South Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '135'},
#  {'LocationAbbr': 'SD',
#   'LocationDesc': 'South Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '22'},
#  {'LocationAbbr': 'TN',
#   'LocationDesc': 'Tennessee',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '213'},
#  {'LocationAbbr': 'TX',
#   'LocationDesc': 'Texas',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '544'},
#  {'LocationAbbr': 'US',
#   'LocationDesc': 'United States',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '9071'},
#  {'LocationAbbr': 'UT',
#   'LocationDesc': 'Utah',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '79'},
#  {'LocationAbbr': 'VT',
#   'LocationDesc': 'Vermont',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '23'},
#  {'LocationAbbr': 'VA',
#   'LocationDesc': 'Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '239'},
#  {'LocationAbbr': 'WA',
#   'LocationDesc': 'Washington',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '209'},
#  {'LocationAbbr': 'WV',
#   'LocationDesc': 'West Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '76'},
#  {'LocationAbbr': 'WI',
#   'LocationDesc': 'Wisconsin',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '176'},
#  {'LocationAbbr': 'WY',
#   'LocationDesc': 'Wyoming',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '18'}]

# %%
# Upload melanoma mortality data to MongoDB
for mortality_data in range(len(mortality_dict)):
    collection.insert_one(mortality_dict[mortality_data])

# %%
# Display the MongoDB records created above
melanoma_mortality_records = db.melanoma_mortality.find()
for melanoma_mortality_record in melanoma_mortality_records:
    print(melanoma_mortality_record)
# Out:
# {'_id': ObjectId('5e81103df0d19231df80657b'), 'LocationAbbr': 'AL', 'LocationDesc': 'Alabama', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '151'}
# {'_id': ObjectId('5e81103df0d19231df80657c'), 'LocationAbbr': 'AK', 'LocationDesc': 'Alaska', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '12'}
# {'_id': ObjectId('5e81103df0d19231df80657d'), 'LocationAbbr': 'AZ', 'LocationDesc': 'Arizona', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '203'}
# {'_id': ObjectId('5e81103df0d19231df80657e'), 'LocationAbbr': 'AR', 'LocationDesc': 'Arkansas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '93'}
# {'_id': ObjectId('5e81103df0d19231df80657f'), 'LocationAbbr': 'CA', 'LocationDesc': 'California', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '943'}
# {'_id': ObjectId('5e81103df0d19231df806580'), 'LocationAbbr': 'CO', 'LocationDesc': 'Colorado', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '161'}
# {'_id': ObjectId('5e81103df0d19231df806581'), 'LocationAbbr': 'CT', 'LocationDesc': 'Connecticut', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '106'}
# {'_id': ObjectId('5e81103df0d19231df806582'), 'LocationAbbr': 'DE', 'LocationDesc': 'Delaware', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '29'}
# {'_id': ObjectId('5e81103df0d19231df806583'), 'LocationAbbr': 'DC', 'LocationDesc': 'District of Columbia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '7'}
# {'_id': ObjectId('5e81103df0d19231df806584'), 'LocationAbbr': 'FL', 'LocationDesc': 'Florida', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '728'}
# {'_id': ObjectId('5e81103df0d19231df806585'), 'LocationAbbr': 'GA', 'LocationDesc': 'Georgia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '217'}
# {'_id': ObjectId('5e81103df0d19231df806586'), 'LocationAbbr': 'HI', 'LocationDesc': 'Hawaii', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '24'}
# {'_id': ObjectId('5e81103df0d19231df806587'), 'LocationAbbr': 'ID', 'LocationDesc': 'Idaho', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '55'}
# {'_id': ObjectId('5e81103df0d19231df806588'), 'LocationAbbr': 'IL', 'LocationDesc': 'Illinois', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '328'}
# {'_id': ObjectId('5e81103df0d19231df806589'), 'LocationAbbr': 'IN', 'LocationDesc': 'Indiana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '215'}
# {'_id': ObjectId('5e81103df0d19231df80658a'), 'LocationAbbr': 'IA', 'LocationDesc': 'Iowa', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '106'}
# {'_id': ObjectId('5e81103df0d19231df80658b'), 'LocationAbbr': 'KS', 'LocationDesc': 'Kansas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '93'}
# {'_id': ObjectId('5e81103df0d19231df80658c'), 'LocationAbbr': 'KY', 'LocationDesc': 'Kentucky', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '151'}
# {'_id': ObjectId('5e81103df0d19231df80658d'), 'LocationAbbr': 'LA', 'LocationDesc': 'Louisiana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '105'}
# {'_id': ObjectId('5e81103df0d19231df80658e'), 'LocationAbbr': 'ME', 'LocationDesc': 'Maine', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '51'}
# {'_id': ObjectId('5e81103df0d19231df80658f'), 'LocationAbbr': 'MD', 'LocationDesc': 'Maryland', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '160'}
# {'_id': ObjectId('5e81103df0d19231df806590'), 'LocationAbbr': 'MA', 'LocationDesc': 'Massachusetts', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '219'}
# {'_id': ObjectId('5e81103df0d19231df806591'), 'LocationAbbr': 'MI', 'LocationDesc': 'Michigan', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '275'}
# {'_id': ObjectId('5e81103df0d19231df806592'), 'LocationAbbr': 'MN', 'LocationDesc': 'Minnesota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '144'}
# {'_id': ObjectId('5e81103df0d19231df806593'), 'LocationAbbr': 'MS', 'LocationDesc': 'Mississippi', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '71'}
# {'_id': ObjectId('5e81103df0d19231df806594'), 'LocationAbbr': 'MO', 'LocationDesc': 'Missouri', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '208'}
# {'_id': ObjectId('5e81103df0d19231df806595'), 'LocationAbbr': 'MT', 'LocationDesc': 'Montana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '36'}
# {'_id': ObjectId('5e81103df0d19231df806596'), 'LocationAbbr': 'NE', 'LocationDesc': 'Nebraska', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '63'}
# {'_id': ObjectId('5e81103df0d19231df806597'), 'LocationAbbr': 'NV', 'LocationDesc': 'Nevada', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '80'}
# {'_id': ObjectId('5e81103df0d19231df806598'), 'LocationAbbr': 'NH', 'LocationDesc': 'New Hampshire', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '42'}
# {'_id': ObjectId('5e81103df0d19231df806599'), 'LocationAbbr': 'NJ', 'LocationDesc': 'New Jersey', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '245'}
# {'_id': ObjectId('5e81103df0d19231df80659a'), 'LocationAbbr': 'NM', 'LocationDesc': 'New Mexico', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '60'}
# {'_id': ObjectId('5e81103df0d19231df80659b'), 'LocationAbbr': 'NY', 'LocationDesc': 'New York', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '484'}
# {'_id': ObjectId('5e81103df0d19231df80659c'), 'LocationAbbr': 'NC', 'LocationDesc': 'North Carolina', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '296'}
# {'_id': ObjectId('5e81103df0d19231df80659d'), 'LocationAbbr': 'ND', 'LocationDesc': 'North Dakota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '17'}
# {'_id': ObjectId('5e81103df0d19231df80659e'), 'LocationAbbr': 'OH', 'LocationDesc': 'Ohio', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '391'}
# {'_id': ObjectId('5e81103df0d19231df80659f'), 'LocationAbbr': 'OK', 'LocationDesc': 'Oklahoma', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '130'}
# {'_id': ObjectId('5e81103df0d19231df8065a0'), 'LocationAbbr': 'OR', 'LocationDesc': 'Oregon', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '147'}
# {'_id': ObjectId('5e81103df0d19231df8065a1'), 'LocationAbbr': 'PA', 'LocationDesc': 'Pennsylvania', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '459'}
# {'_id': ObjectId('5e81103df0d19231df8065a2'), 'LocationAbbr': 'RI', 'LocationDesc': 'Rhode Island', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '32'}
# {'_id': ObjectId('5e81103df0d19231df8065a3'), 'LocationAbbr': 'SC', 'LocationDesc': 'South Carolina', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '135'}
# {'_id': ObjectId('5e81103df0d19231df8065a4'), 'LocationAbbr': 'SD', 'LocationDesc': 'South Dakota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '22'}
# {'_id': ObjectId('5e81103df0d19231df8065a5'), 'LocationAbbr': 'TN', 'LocationDesc': 'Tennessee', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '213'}
# {'_id': ObjectId('5e81103df0d19231df8065a6'), 'LocationAbbr': 'TX', 'LocationDesc': 'Texas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '544'}
# {'_id': ObjectId('5e81103df0d19231df8065a7'), 'LocationAbbr': 'US', 'LocationDesc': 'United States', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '9071'}
# {'_id': ObjectId('5e81103df0d19231df8065a8'), 'LocationAbbr': 'UT', 'LocationDesc': 'Utah', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '79'}
# {'_id': ObjectId('5e81103df0d19231df8065a9'), 'LocationAbbr': 'VT', 'LocationDesc': 'Vermont', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '23'}
# {'_id': ObjectId('5e81103df0d19231df8065aa'), 'LocationAbbr': 'VA', 'LocationDesc': 'Virginia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '239'}
# {'_id': ObjectId('5e81103df0d19231df8065ab'), 'LocationAbbr': 'WA', 'LocationDesc': 'Washington', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '209'}
# {'_id': ObjectId('5e81103df0d19231df8065ac'), 'LocationAbbr': 'WV', 'LocationDesc': 'West Virginia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '76'}
# {'_id': ObjectId('5e81103df0d19231df8065ad'), 'LocationAbbr': 'WI', 'LocationDesc': 'Wisconsin', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '176'}
# {'_id': ObjectId('5e81103df0d19231df8065ae'), 'LocationAbbr': 'WY', 'LocationDesc': 'Wyoming', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '18'}

# %% [markdown]
# #### 3. UV Exposure Data

# %%
# Define database and collection
db = client.uv_melanoma_db
collection = db.uv

# %%
# Convert the data frame of UV exposure data to dictionary
UV_dict = UV_data_df.to_dict("records")
UV_dict
# Out:
# [{'STATENAME': 'Alabama', 'UV_ Wh/m²': 4505.164179104478},
#  {'STATENAME': 'Arizona', 'UV_ Wh/m²': 5528.466666666666},
#  {'STATENAME': 'Arkansas', 'UV_ Wh/m²': 4515.346666666666},
#  {'STATENAME': 'California', 'UV_ Wh/m²': 4871.413793103448},
#  {'STATENAME': 'Colorado', 'UV_ Wh/m²': 4802.730158730159},
#  {'STATENAME': 'Connecticut', 'UV_ Wh/m²': 3832.5},
#  {'STATENAME': 'Delaware', 'UV_ Wh/m²': 4074.0},
#  {'STATENAME': 'District of Columbia', 'UV_ Wh/m²': 4100.0},
#  {'STATENAME': 'Florida', 'UV_ Wh/m²': 4743.671641791045},
#  {'STATENAME': 'Georgia', 'UV_ Wh/m²': 4563.974842767296},
#  {'STATENAME': 'Idaho', 'UV_ Wh/m²': 4170.545454545455},
#  {'STATENAME': 'Illinois', 'UV_ Wh/m²': 4117.4607843137255},
#  {'STATENAME': 'Indiana', 'UV_ Wh/m²': 4019.3804347826085},
#  {'STATENAME': 'Iowa', 'UV_ Wh/m²': 4053.5454545454545},
#  {'STATENAME': 'Kansas', 'UV_ Wh/m²': 4572.047619047619},
#  {'STATENAME': 'Kentucky', 'UV_ Wh/m²': 4113.825},
#  {'STATENAME': 'Louisiana', 'UV_ Wh/m²': 4557.875},
#  {'STATENAME': 'Maine', 'UV_ Wh/m²': 3779.375},
#  {'STATENAME': 'Maryland', 'UV_ Wh/m²': 4057.1666666666665},
#  {'STATENAME': 'Massachusetts', 'UV_ Wh/m²': 3874.785714285714},
#  {'STATENAME': 'Michigan', 'UV_ Wh/m²': 3715.867469879518},
#  {'STATENAME': 'Minnesota', 'UV_ Wh/m²': 3841.022988505747},
#  {'STATENAME': 'Mississippi', 'UV_ Wh/m²': 4518.817073170731},
#  {'STATENAME': 'Missouri', 'UV_ Wh/m²': 4308.339130434782},
#  {'STATENAME': 'Montana', 'UV_ Wh/m²': 3927.964285714286},
#  {'STATENAME': 'Nebraska', 'UV_ Wh/m²': 4350.763440860215},
#  {'STATENAME': 'Nevada', 'UV_ Wh/m²': 4977.0},
#  {'STATENAME': 'New Hampshire', 'UV_ Wh/m²': 3841.5},
#  {'STATENAME': 'New Jersey', 'UV_ Wh/m²': 3951.095238095238},
#  {'STATENAME': 'New Mexico', 'UV_ Wh/m²': 5439.69696969697},
#  {'STATENAME': 'New York', 'UV_ Wh/m²': 3745.1290322580644},
#  {'STATENAME': 'North Carolina', 'UV_ Wh/m²': 4352.17},
#  {'STATENAME': 'North Dakota', 'UV_ Wh/m²': 3902.1132075471696},
#  {'STATENAME': 'Ohio', 'UV_ Wh/m²': 3842.056818181818},
#  {'STATENAME': 'Oklahoma', 'UV_ Wh/m²': 4714.7532467532465},
#  {'STATENAME': 'Oregon', 'UV_ Wh/m²': 3977.777777777778},
#  {'STATENAME': 'Pennsylvania', 'UV_ Wh/m²': 3809.208955223881},
#  {'STATENAME': 'Rhode Island', 'UV_ Wh/m²': 3881.4},
#  {'STATENAME': 'South Carolina', 'UV_ Wh/m²': 4525.021739130435},
#  {'STATENAME': 'South Dakota', 'UV_ Wh/m²': 4111.742424242424},
#  {'STATENAME': 'Tennessee', 'UV_ Wh/m²': 4278.578947368421},
#  {'STATENAME': 'Texas', 'UV_ Wh/m²': 4917.952755905511},
#  {'STATENAME': 'Utah', 'UV_ Wh/m²': 4737.551724137931},
#  {'STATENAME': 'Vermont', 'UV_ Wh/m²': 3744.0714285714284},
#  {'STATENAME': 'Virginia', 'UV_ Wh/m²': 4181.985074626866},
#  {'STATENAME': 'Washington', 'UV_ Wh/m²': 3594.102564102564},
#  {'STATENAME': 'West Virginia', 'UV_ Wh/m²': 3892.3636363636365},
#  {'STATENAME': 'Wisconsin', 'UV_ Wh/m²': 3810.7083333333335},
#  {'STATENAME': 'Wyoming', 'UV_ Wh/m²': 4350.521739130435}]

# %%
# Upload UV exposure data to MongoDB
for UV_data in range(len(UV_dict)):
    collection.insert_one(UV_dict[UV_data])

# %%
# Display the MongoDB records created above
UV_records = db.uv.find()
for UV_record in UV_records:
    print(UV_record)
# Out:
# {'_id': ObjectId('5e8110a8f0d19231df8065af'), 'STATENAME': 'Alabama', 'UV_ Wh/m²': 4505.164179104478}
# {'_id': ObjectId('5e8110a9f0d19231df8065b0'), 'STATENAME': 'Arizona', 'UV_ Wh/m²': 5528.466666666666}
# {'_id': ObjectId('5e8110a9f0d19231df8065b1'), 'STATENAME': 'Arkansas', 'UV_ Wh/m²': 4515.346666666666}
# {'_id': ObjectId('5e8110a9f0d19231df8065b2'), 'STATENAME': 'California', 'UV_ Wh/m²': 4871.413793103448}
# {'_id': ObjectId('5e8110a9f0d19231df8065b3'), 'STATENAME': 'Colorado', 'UV_ Wh/m²': 4802.730158730159}
# {'_id': ObjectId('5e8110a9f0d19231df8065b4'), 'STATENAME': 'Connecticut', 'UV_ Wh/m²': 3832.5}
# {'_id': ObjectId('5e8110a9f0d19231df8065b5'), 'STATENAME': 'Delaware', 'UV_ Wh/m²': 4074.0}
# {'_id': ObjectId('5e8110a9f0d19231df8065b6'), 'STATENAME': 'District of Columbia', 'UV_ Wh/m²': 4100.0}
# {'_id': ObjectId('5e8110a9f0d19231df8065b7'), 'STATENAME': 'Florida', 'UV_ Wh/m²': 4743.671641791045}
# {'_id': ObjectId('5e8110a9f0d19231df8065b8'), 'STATENAME': 'Georgia', 'UV_ Wh/m²': 4563.974842767296}
# {'_id': ObjectId('5e8110a9f0d19231df8065b9'), 'STATENAME': 'Idaho', 'UV_ Wh/m²': 4170.545454545455}
# {'_id': ObjectId('5e8110a9f0d19231df8065ba'), 'STATENAME': 'Illinois', 'UV_ Wh/m²': 4117.4607843137255}
# {'_id': ObjectId('5e8110a9f0d19231df8065bb'), 'STATENAME': 'Indiana', 'UV_ Wh/m²': 4019.3804347826085}
# {'_id': ObjectId('5e8110a9f0d19231df8065bc'), 'STATENAME': 'Iowa', 'UV_ Wh/m²': 4053.5454545454545}
# {'_id': ObjectId('5e8110a9f0d19231df8065bd'), 'STATENAME': 'Kansas', 'UV_ Wh/m²': 4572.047619047619}
# {'_id': ObjectId('5e8110a9f0d19231df8065be'), 'STATENAME': 'Kentucky', 'UV_ Wh/m²': 4113.825}
# {'_id': ObjectId('5e8110a9f0d19231df8065bf'), 'STATENAME': 'Louisiana', 'UV_ Wh/m²': 4557.875}
# {'_id': ObjectId('5e8110a9f0d19231df8065c0'), 'STATENAME': 'Maine', 'UV_ Wh/m²': 3779.375}
# {'_id': ObjectId('5e8110a9f0d19231df8065c1'), 'STATENAME': 'Maryland', 'UV_ Wh/m²': 4057.1666666666665}
# {'_id': ObjectId('5e8110a9f0d19231df8065c2'), 'STATENAME': 'Massachusetts', 'UV_ Wh/m²': 3874.785714285714}
# {'_id': ObjectId('5e8110a9f0d19231df8065c3'), 'STATENAME': 'Michigan', 'UV_ Wh/m²': 3715.867469879518}
# {'_id': ObjectId('5e8110a9f0d19231df8065c4'), 'STATENAME': 'Minnesota', 'UV_ Wh/m²': 3841.022988505747}
# {'_id': ObjectId('5e8110a9f0d19231df8065c5'), 'STATENAME': 'Mississippi', 'UV_ Wh/m²': 4518.817073170731}
# {'_id': ObjectId('5e8110a9f0d19231df8065c6'), 'STATENAME': 'Missouri', 'UV_ Wh/m²': 4308.339130434782}
# {'_id': ObjectId('5e8110a9f0d19231df8065c7'), 'STATENAME': 'Montana', 'UV_ Wh/m²': 3927.964285714286}
# {'_id': ObjectId('5e8110a9f0d19231df8065c8'), 'STATENAME': 'Nebraska', 'UV_ Wh/m²': 4350.763440860215}
# {'_id': ObjectId('5e8110a9f0d19231df8065c9'), 'STATENAME': 'Nevada', 'UV_ Wh/m²': 4977.0}
# {'_id': ObjectId('5e8110a9f0d19231df8065ca'), 'STATENAME': 'New Hampshire', 'UV_ Wh/m²': 3841.5}
# {'_id': ObjectId('5e8110a9f0d19231df8065cb'), 'STATENAME': 'New Jersey', 'UV_ Wh/m²': 3951.095238095238}
# {'_id': ObjectId('5e8110a9f0d19231df8065cc'), 'STATENAME': 'New Mexico', 'UV_ Wh/m²': 5439.69696969697}
# {'_id': ObjectId('5e8110a9f0d19231df8065cd'), 'STATENAME': 'New York', 'UV_ Wh/m²': 3745.1290322580644}
# {'_id': ObjectId('5e8110a9f0d19231df8065ce'), 'STATENAME': 'North Carolina', 'UV_ Wh/m²': 4352.17}
# {'_id': ObjectId('5e8110a9f0d19231df8065cf'), 'STATENAME': 'North Dakota', 'UV_ Wh/m²': 3902.1132075471696}
# {'_id': ObjectId('5e8110a9f0d19231df8065d0'), 'STATENAME': 'Ohio', 'UV_ Wh/m²': 3842.056818181818}
# {'_id': ObjectId('5e8110a9f0d19231df8065d1'), 'STATENAME': 'Oklahoma', 'UV_ Wh/m²': 4714.7532467532465}
# {'_id': ObjectId('5e8110a9f0d19231df8065d2'), 'STATENAME': 'Oregon', 'UV_ Wh/m²': 3977.777777777778}
# {'_id': ObjectId('5e8110a9f0d19231df8065d3'), 'STATENAME': 'Pennsylvania', 'UV_ Wh/m²': 3809.208955223881}
# {'_id': ObjectId('5e8110a9f0d19231df8065d4'), 'STATENAME': 'Rhode Island', 'UV_ Wh/m²': 3881.4}
# {'_id': ObjectId('5e8110a9f0d19231df8065d5'), 'STATENAME': 'South Carolina', 'UV_ Wh/m²': 4525.021739130435}
# {'_id': ObjectId('5e8110a9f0d19231df8065d6'), 'STATENAME': 'South Dakota', 'UV_ Wh/m²': 4111.742424242424}
# {'_id': ObjectId('5e8110a9f0d19231df8065d7'), 'STATENAME': 'Tennessee', 'UV_ Wh/m²': 4278.578947368421}
# {'_id': ObjectId('5e8110a9f0d19231df8065d8'), 'STATENAME': 'Texas', 'UV_ Wh/m²': 4917.952755905511}
# {'_id': ObjectId('5e8110a9f0d19231df8065d9'), 'STATENAME': 'Utah', 'UV_ Wh/m²': 4737.551724137931}
# {'_id': ObjectId('5e8110a9f0d19231df8065da'), 'STATENAME': 'Vermont', 'UV_ Wh/m²': 3744.0714285714284}
# {'_id': ObjectId('5e8110a9f0d19231df8065db'), 'STATENAME': 'Virginia', 'UV_ Wh/m²': 4181.985074626866}
# {'_id': ObjectId('5e8110a9f0d19231df8065dc'), 'STATENAME': 'Washington', 'UV_ Wh/m²': 3594.102564102564}
# {'_id': ObjectId('5e8110a9f0d19231df8065dd'), 'STATENAME': 'West Virginia', 'UV_ Wh/m²': 3892.3636363636365}
# {'_id': ObjectId('5e8110a9f0d19231df8065de'), 'STATENAME': 'Wisconsin', 'UV_ Wh/m²': 3810.7083333333335}
# {'_id': ObjectId('5e8110a9f0d19231df8065df'), 'STATENAME': 'Wyoming', 'UV_ Wh/m²': 4350.521739130435}

# %% [markdown]
# PLAN:
# - Dropdown for each states
# - Map showing the UV exposure and layers for incidence and mortality

# %%
# CLEANING WITH PANDAS - DONE
# MONGODB - DONE
# FLASK APP
# VISUALIZATIONS (JS)
# WEB DEPLOYMENT
