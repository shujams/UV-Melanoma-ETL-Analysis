# %% [markdown]
# # ETL & Visualization Project

# %% [markdown]
# ## UV Exposure & Melanoma Rates Correlation in United States

# %% [markdown]
# ### Extract: UV Exposure and Melanoma Data (csv)

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import pandas as pd
from sqlalchemy import create_engine
# from scipy.stats import linregress
# from scipy import stats
# import pingouin as pg # Install pingouin stats package (pip install pingouin)
# import seaborn as sns # Install seaborn data visualization library (pip install seaborn)
# from scipy.stats import pearsonr

yr_list= [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
       2014, 2015]

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load
CDI_data_to_load = "CDI_data.csv"

# Read the Population Health Data
CDI_data_pd = pd.read_csv(CDI_data_to_load, encoding="utf-8").fillna(0)

# Display the data table for preview
CDI_data_pd
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0            2013     2013           CA            California      YRBSS
# 1            2013     2013           CO              Colorado      YRBSS
# 2            2013     2013           CT           Connecticut      YRBSS
# 3            2013     2013           DC  District of Columbia      YRBSS
# 4            2013     2013           DE              Delaware      YRBSS
# ...           ...      ...          ...                   ...        ...
# 237956       2012     2012           WI             Wisconsin      BRFSS
# 237957       2012     2012           WY               Wyoming      BRFSS
# 237958       2012     2012           GU                  Guam      BRFSS
# 237959       2012     2012           PR           Puerto Rico      BRFSS
# 237960       2012     2012           VI        Virgin Islands      BRFSS
#
#                Topic                                           Question  \
# 0            Alcohol                            Alcohol use among youth
# 1            Alcohol                            Alcohol use among youth
# 2            Alcohol                            Alcohol use among youth
# 3            Alcohol                            Alcohol use among youth
# 4            Alcohol                            Alcohol use among youth
# ...              ...                                                ...
# 237956  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237957  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237958  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237959  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237960  Older Adults  Proportion of older adults aged 50-64 years wh...
#
#        Response DataValueUnit DataValueTypeID  ... TopicID QuestionID  \
# 0             0             %         CrdPrev  ...     ALC     ALC1_1
# 1             0             %         CrdPrev  ...     ALC     ALC1_1
# 2             0             %         CrdPrev  ...     ALC     ALC1_1
# 3             0             %         CrdPrev  ...     ALC     ALC1_1
# 4             0             %         CrdPrev  ...     ALC     ALC1_1
# ...         ...           ...             ...  ...     ...        ...
# 237956        0             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237957        0             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237958        0             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237959        0             %      AgeAdjPrev  ...     OLD     OLD3_2
# 237960        0             %      AgeAdjPrev  ...     OLD     OLD3_2
#
#         ResponseID LocationID StratificationCategoryID1  StratificationID1  \
# 0                0          6                   OVERALL                OVR
# 1                0          8                   OVERALL                OVR
# 2                0          9                   OVERALL                OVR
# 3                0         11                   OVERALL                OVR
# 4                0         10                   OVERALL                OVR
# ...            ...        ...                       ...                ...
# 237956           0         55                      RACE                MRC
# 237957           0         56                      RACE                MRC
# 237958           0         66                      RACE                MRC
# 237959           0         72                      RACE                MRC
# 237960           0         78                      RACE                MRC
#
#         StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                               0                 0                         0
# 1                               0                 0                         0
# 2                               0                 0                         0
# 3                               0                 0                         0
# 4                               0                 0                         0
# ...                           ...               ...                       ...
# 237956                          0                 0                         0
# 237957                          0                 0                         0
# 237958                          0                 0                         0
# 237959                          0                 0                         0
# 237960                          0                 0                         0
#
#        StratificationID3
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 237956                 0
# 237957                 0
# 237958                 0
# 237959                 0
# 237960                 0
#
# [237961 rows x 34 columns]

# %%
# Extracting cancer data

topic_sorted_df = CDI_data_pd.groupby('Topic')
topic_sorted_df
cancer_df = topic_sorted_df.get_group('Cancer') 
cancer_df
cancer_df = cancer_df.sort_values('LocationDesc')
cancer_df[[]]

new_cancer_df = cancer_df[['LocationAbbr','LocationDesc','Topic',
                                        'Question','DataValueType','DataValue']].copy()
new_cancer_df
# Out:
#       LocationAbbr LocationDesc   Topic  \
# 49892           AL      Alabama  Cancer
# 50608           AL      Alabama  Cancer
# 50607           AL      Alabama  Cancer
# 50606           AL      Alabama  Cancer
# 48310           AL      Alabama  Cancer
# ...            ...          ...     ...
# 48305           WY      Wyoming  Cancer
# 48304           WY      Wyoming  Cancer
# 48150           WY      Wyoming  Cancer
# 49865           WY      Wyoming  Cancer
# 53427           WY      Wyoming  Cancer
#
#                                                 Question  \
# 49892  Recent Papanicolaou smear use among women aged...
# 50608  Fecal occult blood test, sigmoidoscopy, or col...
# 50607  Fecal occult blood test, sigmoidoscopy, or col...
# 50606  Fecal occult blood test, sigmoidoscopy, or col...
# 48310                  Cancer of the prostate, mortality
# ...                                                  ...
# 48305         Invasive cancer of the prostate, incidence
# 48304         Invasive cancer of the prostate, incidence
# 48150   Cancer of the oral cavity and pharynx, mortality
# 49865  Papanicolaou smear use among adult women aged ...
# 53427                                Melanoma, mortality
#
#                           DataValueType DataValue
# 49892                  Crude Prevalence         0
# 50608                  Crude Prevalence      61.8
# 50607           Age-adjusted Prevalence      62.6
# 50606                  Crude Prevalence        64
# 48310  Average Annual Age-adjusted Rate      26.4
# ...                                 ...       ...
# 48305         Average Annual Crude Rate     138.4
# 48304  Average Annual Age-adjusted Rate     127.1
# 48150             Average Annual Number        17
# 49865                  Crude Prevalence         0
# 53427             Average Annual Number        18
#
# [7001 rows x 6 columns]

# %%
# Cancer Incidence Values for Continental United States

incidence_df = new_cancer_df.loc[new_cancer_df['Question'] == 'Invasive melanoma, incidence']
# incidence_df

incidence_df = incidence_df.loc[incidence_df['DataValueType'] == 'Average Annual Number']
# incidence_df.set_index('LocationAbbr', inplace=True)
# incidence_df.to_csv('incidence.csv')
# incidence_df.drop(["AK", "HI", "US"], inplace = True) 
incidence_df = incidence_df[incidence_df['LocationAbbr'] != 'AK']
incidence_df = incidence_df[incidence_df['LocationAbbr'] != 'HI']
incidence_df = incidence_df[incidence_df['LocationAbbr'] != 'US']
incidence_df
# Out:
#       LocationAbbr          LocationDesc   Topic  \
# 53122           AL               Alabama  Cancer
# 53128           AZ               Arizona  Cancer
# 53125           AR              Arkansas  Cancer
# 53131           CA            California  Cancer
# 53134           CO              Colorado  Cancer
# 53137           CT           Connecticut  Cancer
# 53143           DE              Delaware  Cancer
# 53140           DC  District of Columbia  Cancer
# 53146           FL               Florida  Cancer
# 53149           GA               Georgia  Cancer
# 53158           ID                 Idaho  Cancer
# 53161           IL              Illinois  Cancer
# 53164           IN               Indiana  Cancer
# 53155           IA                  Iowa  Cancer
# 53167           KS                Kansas  Cancer
# 53170           KY              Kentucky  Cancer
# 53173           LA             Louisiana  Cancer
# 53182           ME                 Maine  Cancer
# 53179           MD              Maryland  Cancer
# 53176           MA         Massachusetts  Cancer
# 53185           MI              Michigan  Cancer
# 53188           MN             Minnesota  Cancer
# 53194           MS           Mississippi  Cancer
# 53191           MO              Missouri  Cancer
# 53197           MT               Montana  Cancer
# 53206           NE              Nebraska  Cancer
# 53218           NV                Nevada  Cancer
# 53209           NH         New Hampshire  Cancer
# 53212           NJ            New Jersey  Cancer
# 53215           NM            New Mexico  Cancer
# 53221           NY              New York  Cancer
# 53200           NC        North Carolina  Cancer
# 53203           ND          North Dakota  Cancer
# 53224           OH                  Ohio  Cancer
# 53227           OK              Oklahoma  Cancer
# 53230           OR                Oregon  Cancer
# 53233           PA          Pennsylvania  Cancer
# 53236           RI          Rhode Island  Cancer
# 53239           SC        South Carolina  Cancer
# 53242           SD          South Dakota  Cancer
# 53245           TN             Tennessee  Cancer
# 53248           TX                 Texas  Cancer
# 53254           UT                  Utah  Cancer
# 53260           VT               Vermont  Cancer
# 53257           VA              Virginia  Cancer
# 53263           WA            Washington  Cancer
# 53271           WV         West Virginia  Cancer
# 53268           WI             Wisconsin  Cancer
# 53274           WY               Wyoming  Cancer
#
#                            Question          DataValueType DataValue
# 53122  Invasive melanoma, incidence  Average Annual Number      1128
# 53128  Invasive melanoma, incidence  Average Annual Number      1135
# 53125  Invasive melanoma, incidence  Average Annual Number       534
# 53131  Invasive melanoma, incidence  Average Annual Number      7740
# 53134  Invasive melanoma, incidence  Average Annual Number      1113
# 53137  Invasive melanoma, incidence  Average Annual Number       902
# 53143  Invasive melanoma, incidence  Average Annual Number       293
# 53140  Invasive melanoma, incidence  Average Annual Number        49
# 53146  Invasive melanoma, incidence  Average Annual Number      4692
# 53149  Invasive melanoma, incidence  Average Annual Number      2194
# 53158  Invasive melanoma, incidence  Average Annual Number       405
# 53161  Invasive melanoma, incidence  Average Annual Number      2399
# 53164  Invasive melanoma, incidence  Average Annual Number      1223
# 53155  Invasive melanoma, incidence  Average Annual Number       798
# 53167  Invasive melanoma, incidence  Average Annual Number       712
# 53170  Invasive melanoma, incidence  Average Annual Number      1130
# 53173  Invasive melanoma, incidence  Average Annual Number       714
# 53182  Invasive melanoma, incidence  Average Annual Number       370
# 53179  Invasive melanoma, incidence  Average Annual Number      1272
# 53176  Invasive melanoma, incidence  Average Annual Number      1590
# 53185  Invasive melanoma, incidence  Average Annual Number      2053
# 53188  Invasive melanoma, incidence  Average Annual Number      1530
# 53194  Invasive melanoma, incidence  Average Annual Number       538
# 53191  Invasive melanoma, incidence  Average Annual Number      1177
# 53197  Invasive melanoma, incidence  Average Annual Number       268
# 53206  Invasive melanoma, incidence  Average Annual Number       356
# 53218  Invasive melanoma, incidence  Average Annual Number         0
# 53209  Invasive melanoma, incidence  Average Annual Number       400
# 53212  Invasive melanoma, incidence  Average Annual Number      2093
# 53215  Invasive melanoma, incidence  Average Annual Number       406
# 53221  Invasive melanoma, incidence  Average Annual Number      3717
# 53200  Invasive melanoma, incidence  Average Annual Number      2302
# 53203  Invasive melanoma, incidence  Average Annual Number       158
# 53224  Invasive melanoma, incidence  Average Annual Number      2491
# 53227  Invasive melanoma, incidence  Average Annual Number       654
# 53230  Invasive melanoma, incidence  Average Annual Number      1140
# 53233  Invasive melanoma, incidence  Average Annual Number      3045
# 53236  Invasive melanoma, incidence  Average Annual Number       252
# 53239  Invasive melanoma, incidence  Average Annual Number      1144
# 53242  Invasive melanoma, incidence  Average Annual Number       167
# 53245  Invasive melanoma, incidence  Average Annual Number      1431
# 53248  Invasive melanoma, incidence  Average Annual Number      3025
# 53254  Invasive melanoma, incidence  Average Annual Number       742
# 53260  Invasive melanoma, incidence  Average Annual Number       215
# 53257  Invasive melanoma, incidence  Average Annual Number      1535
# 53263  Invasive melanoma, incidence  Average Annual Number      1821
# 53271  Invasive melanoma, incidence  Average Annual Number       464
# 53268  Invasive melanoma, incidence  Average Annual Number      1284
# 53274  Invasive melanoma, incidence  Average Annual Number       135

# %%
# Cancer Mortality Values for Continental United States

mortality_df = new_cancer_df.loc[new_cancer_df['Question'] == 'Melanoma, mortality']
mortality_df

mortality_df = mortality_df.loc[mortality_df['DataValueType'] == 'Average Annual Number']
# mortality_df.set_index('LocationAbbr', inplace=True)
# mortality_df.to_csv('mortality.csv')
# mortality_df.drop(["AK", "HI", "US"], inplace = True) 
mortality_df = mortality_df[mortality_df['LocationAbbr'] != 'AK']
mortality_df = mortality_df[mortality_df['LocationAbbr'] != 'HI']
mortality_df = mortality_df[mortality_df['LocationAbbr'] != 'US']
mortality_df
# Out:
#       LocationAbbr          LocationDesc   Topic             Question  \
# 53280           AL               Alabama  Cancer  Melanoma, mortality
# 53286           AZ               Arizona  Cancer  Melanoma, mortality
# 53283           AR              Arkansas  Cancer  Melanoma, mortality
# 53289           CA            California  Cancer  Melanoma, mortality
# 53292           CO              Colorado  Cancer  Melanoma, mortality
# 53295           CT           Connecticut  Cancer  Melanoma, mortality
# 53301           DE              Delaware  Cancer  Melanoma, mortality
# 53298           DC  District of Columbia  Cancer  Melanoma, mortality
# 53304           FL               Florida  Cancer  Melanoma, mortality
# 53307           GA               Georgia  Cancer  Melanoma, mortality
# 53265           ID                 Idaho  Cancer  Melanoma, mortality
# 53318           IL              Illinois  Cancer  Melanoma, mortality
# 53321           IN               Indiana  Cancer  Melanoma, mortality
# 53313           IA                  Iowa  Cancer  Melanoma, mortality
# 53324           KS                Kansas  Cancer  Melanoma, mortality
# 53327           KY              Kentucky  Cancer  Melanoma, mortality
# 53330           LA             Louisiana  Cancer  Melanoma, mortality
# 53339           ME                 Maine  Cancer  Melanoma, mortality
# 53336           MD              Maryland  Cancer  Melanoma, mortality
# 53333           MA         Massachusetts  Cancer  Melanoma, mortality
# 53342           MI              Michigan  Cancer  Melanoma, mortality
# 53345           MN             Minnesota  Cancer  Melanoma, mortality
# 53351           MS           Mississippi  Cancer  Melanoma, mortality
# 53348           MO              Missouri  Cancer  Melanoma, mortality
# 53354           MT               Montana  Cancer  Melanoma, mortality
# 53363           NE              Nebraska  Cancer  Melanoma, mortality
# 53374           NV                Nevada  Cancer  Melanoma, mortality
# 53266           NH         New Hampshire  Cancer  Melanoma, mortality
# 53368           NJ            New Jersey  Cancer  Melanoma, mortality
# 53371           NM            New Mexico  Cancer  Melanoma, mortality
# 53377           NY              New York  Cancer  Melanoma, mortality
# 53357           NC        North Carolina  Cancer  Melanoma, mortality
# 53360           ND          North Dakota  Cancer  Melanoma, mortality
# 53380           OH                  Ohio  Cancer  Melanoma, mortality
# 53383           OK              Oklahoma  Cancer  Melanoma, mortality
# 53386           OR                Oregon  Cancer  Melanoma, mortality
# 53389           PA          Pennsylvania  Cancer  Melanoma, mortality
# 53392           RI          Rhode Island  Cancer  Melanoma, mortality
# 53395           SC        South Carolina  Cancer  Melanoma, mortality
# 53398           SD          South Dakota  Cancer  Melanoma, mortality
# 53401           TN             Tennessee  Cancer  Melanoma, mortality
# 53404           TX                 Texas  Cancer  Melanoma, mortality
# 53410           UT                  Utah  Cancer  Melanoma, mortality
# 16644           VT               Vermont  Cancer  Melanoma, mortality
# 53413           VA              Virginia  Cancer  Melanoma, mortality
# 53418           WA            Washington  Cancer  Melanoma, mortality
# 53424           WV         West Virginia  Cancer  Melanoma, mortality
# 53421           WI             Wisconsin  Cancer  Melanoma, mortality
# 53427           WY               Wyoming  Cancer  Melanoma, mortality
#
#                DataValueType DataValue
# 53280  Average Annual Number       151
# 53286  Average Annual Number       203
# 53283  Average Annual Number        93
# 53289  Average Annual Number       943
# 53292  Average Annual Number       161
# 53295  Average Annual Number       106
# 53301  Average Annual Number        29
# 53298  Average Annual Number         7
# 53304  Average Annual Number       728
# 53307  Average Annual Number       217
# 53265  Average Annual Number        55
# 53318  Average Annual Number       328
# 53321  Average Annual Number       215
# 53313  Average Annual Number       106
# 53324  Average Annual Number        93
# 53327  Average Annual Number       151
# 53330  Average Annual Number       105
# 53339  Average Annual Number        51
# 53336  Average Annual Number       160
# 53333  Average Annual Number       219
# 53342  Average Annual Number       275
# 53345  Average Annual Number       144
# 53351  Average Annual Number        71
# 53348  Average Annual Number       208
# 53354  Average Annual Number        36
# 53363  Average Annual Number        63
# 53374  Average Annual Number        80
# 53266  Average Annual Number        42
# 53368  Average Annual Number       245
# 53371  Average Annual Number        60
# 53377  Average Annual Number       484
# 53357  Average Annual Number       296
# 53360  Average Annual Number        17
# 53380  Average Annual Number       391
# 53383  Average Annual Number       130
# 53386  Average Annual Number       147
# 53389  Average Annual Number       459
# 53392  Average Annual Number        32
# 53395  Average Annual Number       135
# 53398  Average Annual Number        22
# 53401  Average Annual Number       213
# 53404  Average Annual Number       544
# 53410  Average Annual Number        79
# 16644  Average Annual Number        23
# 53413  Average Annual Number       239
# 53418  Average Annual Number       209
# 53424  Average Annual Number        76
# 53421  Average Annual Number       176
# 53427  Average Annual Number        18

# %%
# 2nd File to Load
UV_data_to_load = "UV_data.csv"
UV_data_df = pd.read_csv(UV_data_to_load, encoding="utf-8").fillna(0)

# Read the Population Health Data
UV_data_df = pd.read_csv(UV_data_to_load)

# # Display the data table for preview
UV_data_df = UV_data_df.groupby("STATENAME", as_index=False)["UV_Wh/square_meter"].mean()
UV_data_df.set_index('STATENAME', inplace=True)
# UV_data_df.to_csv('UV_data_post.csv')
UV_data_df
# Out:
#                       UV_Wh/square_meter
# STATENAME
# Alabama                      4505.164179
# Arizona                      5528.466667
# Arkansas                     4515.346667
# California                   4871.413793
# Colorado                     4802.730159
# Connecticut                  3832.500000
# Delaware                     4074.000000
# District of Columbia         4100.000000
# Florida                      4743.671642
# Georgia                      4563.974843
# Idaho                        4170.545455
# Illinois                     4117.460784
# Indiana                      4019.380435
# Iowa                         4053.545455
# Kansas                       4572.047619
# Kentucky                     4113.825000
# Louisiana                    4557.875000
# Maine                        3779.375000
# Maryland                     4057.166667
# Massachusetts                3874.785714
# Michigan                     3715.867470
# Minnesota                    3841.022989
# Mississippi                  4518.817073
# Missouri                     4308.339130
# Montana                      3927.964286
# Nebraska                     4350.763441
# Nevada                       4977.000000
# New Hampshire                3841.500000
# New Jersey                   3951.095238
# New Mexico                   5439.696970
# New York                     3745.129032
# North Carolina               4352.170000
# North Dakota                 3902.113208
# Ohio                         3842.056818
# Oklahoma                     4714.753247
# Oregon                       3977.777778
# Pennsylvania                 3809.208955
# Rhode Island                 3881.400000
# South Carolina               4525.021739
# South Dakota                 4111.742424
# Tennessee                    4278.578947
# Texas                        4917.952756
# Utah                         4737.551724
# Vermont                      3744.071429
# Virginia                     4181.985075
# Washington                   3594.102564
# West Virginia                3892.363636
# Wisconsin                    3810.708333
# Wyoming                      4350.521739

# %% [markdown]
# ### Load: Database (MongoDB)

# %%
# Dependencies
import pymongo
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %% [markdown]
# #### Upload Clean Data to Database

# %% [markdown]
# #### 1. Melanoma Incidence Data

# %%
# Define database and collection
db = client.uv_melanoma_db
collection = db.melanoma_incidence

# %%
# Convert the data frame of melanoma incidence data to dictionary
incidence_dict = incidence_df.to_dict("records")
incidence_dict
# Out:
# [{'LocationAbbr': 'AL',
#   'LocationDesc': 'Alabama',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1128'},
#  {'LocationAbbr': 'AZ',
#   'LocationDesc': 'Arizona',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1135'},
#  {'LocationAbbr': 'AR',
#   'LocationDesc': 'Arkansas',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '534'},
#  {'LocationAbbr': 'CA',
#   'LocationDesc': 'California',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '7740'},
#  {'LocationAbbr': 'CO',
#   'LocationDesc': 'Colorado',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1113'},
#  {'LocationAbbr': 'CT',
#   'LocationDesc': 'Connecticut',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '902'},
#  {'LocationAbbr': 'DE',
#   'LocationDesc': 'Delaware',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '293'},
#  {'LocationAbbr': 'DC',
#   'LocationDesc': 'District of Columbia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '49'},
#  {'LocationAbbr': 'FL',
#   'LocationDesc': 'Florida',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '4692'},
#  {'LocationAbbr': 'GA',
#   'LocationDesc': 'Georgia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2194'},
#  {'LocationAbbr': 'ID',
#   'LocationDesc': 'Idaho',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '405'},
#  {'LocationAbbr': 'IL',
#   'LocationDesc': 'Illinois',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2399'},
#  {'LocationAbbr': 'IN',
#   'LocationDesc': 'Indiana',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1223'},
#  {'LocationAbbr': 'IA',
#   'LocationDesc': 'Iowa',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '798'},
#  {'LocationAbbr': 'KS',
#   'LocationDesc': 'Kansas',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '712'},
#  {'LocationAbbr': 'KY',
#   'LocationDesc': 'Kentucky',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1130'},
#  {'LocationAbbr': 'LA',
#   'LocationDesc': 'Louisiana',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '714'},
#  {'LocationAbbr': 'ME',
#   'LocationDesc': 'Maine',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '370'},
#  {'LocationAbbr': 'MD',
#   'LocationDesc': 'Maryland',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1272'},
#  {'LocationAbbr': 'MA',
#   'LocationDesc': 'Massachusetts',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1590'},
#  {'LocationAbbr': 'MI',
#   'LocationDesc': 'Michigan',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2053'},
#  {'LocationAbbr': 'MN',
#   'LocationDesc': 'Minnesota',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1530'},
#  {'LocationAbbr': 'MS',
#   'LocationDesc': 'Mississippi',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '538'},
#  {'LocationAbbr': 'MO',
#   'LocationDesc': 'Missouri',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1177'},
#  {'LocationAbbr': 'MT',
#   'LocationDesc': 'Montana',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '268'},
#  {'LocationAbbr': 'NE',
#   'LocationDesc': 'Nebraska',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '356'},
#  {'LocationAbbr': 'NV',
#   'LocationDesc': 'Nevada',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': 0},
#  {'LocationAbbr': 'NH',
#   'LocationDesc': 'New Hampshire',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '400'},
#  {'LocationAbbr': 'NJ',
#   'LocationDesc': 'New Jersey',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2093'},
#  {'LocationAbbr': 'NM',
#   'LocationDesc': 'New Mexico',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '406'},
#  {'LocationAbbr': 'NY',
#   'LocationDesc': 'New York',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '3717'},
#  {'LocationAbbr': 'NC',
#   'LocationDesc': 'North Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2302'},
#  {'LocationAbbr': 'ND',
#   'LocationDesc': 'North Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '158'},
#  {'LocationAbbr': 'OH',
#   'LocationDesc': 'Ohio',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '2491'},
#  {'LocationAbbr': 'OK',
#   'LocationDesc': 'Oklahoma',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '654'},
#  {'LocationAbbr': 'OR',
#   'LocationDesc': 'Oregon',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1140'},
#  {'LocationAbbr': 'PA',
#   'LocationDesc': 'Pennsylvania',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '3045'},
#  {'LocationAbbr': 'RI',
#   'LocationDesc': 'Rhode Island',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '252'},
#  {'LocationAbbr': 'SC',
#   'LocationDesc': 'South Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1144'},
#  {'LocationAbbr': 'SD',
#   'LocationDesc': 'South Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '167'},
#  {'LocationAbbr': 'TN',
#   'LocationDesc': 'Tennessee',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1431'},
#  {'LocationAbbr': 'TX',
#   'LocationDesc': 'Texas',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '3025'},
#  {'LocationAbbr': 'UT',
#   'LocationDesc': 'Utah',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '742'},
#  {'LocationAbbr': 'VT',
#   'LocationDesc': 'Vermont',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '215'},
#  {'LocationAbbr': 'VA',
#   'LocationDesc': 'Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1535'},
#  {'LocationAbbr': 'WA',
#   'LocationDesc': 'Washington',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1821'},
#  {'LocationAbbr': 'WV',
#   'LocationDesc': 'West Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '464'},
#  {'LocationAbbr': 'WI',
#   'LocationDesc': 'Wisconsin',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '1284'},
#  {'LocationAbbr': 'WY',
#   'LocationDesc': 'Wyoming',
#   'Topic': 'Cancer',
#   'Question': 'Invasive melanoma, incidence',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '135'}]

# %%
# Upload melanoma incidence data to MongoDB
for incidence_data in range(len(incidence_dict)):
    collection.insert_one(incidence_dict[incidence_data])

# %%
# Display the MongoDB records created above
melanoma_incidence_records = db.melanoma_incidence.find()
for melanoma_incidence_record in melanoma_incidence_records:
    print(melanoma_incidence_record)
# Out:
# {'_id': ObjectId('5e8827adcaeb91215177c1dc'), 'LocationAbbr': 'AL', 'LocationDesc': 'Alabama', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1128'}
# {'_id': ObjectId('5e8827adcaeb91215177c1dd'), 'LocationAbbr': 'AZ', 'LocationDesc': 'Arizona', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1135'}
# {'_id': ObjectId('5e8827adcaeb91215177c1de'), 'LocationAbbr': 'AR', 'LocationDesc': 'Arkansas', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '534'}
# {'_id': ObjectId('5e8827adcaeb91215177c1df'), 'LocationAbbr': 'CA', 'LocationDesc': 'California', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '7740'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e0'), 'LocationAbbr': 'CO', 'LocationDesc': 'Colorado', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1113'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e1'), 'LocationAbbr': 'CT', 'LocationDesc': 'Connecticut', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '902'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e2'), 'LocationAbbr': 'DE', 'LocationDesc': 'Delaware', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '293'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e3'), 'LocationAbbr': 'DC', 'LocationDesc': 'District of Columbia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '49'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e4'), 'LocationAbbr': 'FL', 'LocationDesc': 'Florida', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '4692'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e5'), 'LocationAbbr': 'GA', 'LocationDesc': 'Georgia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2194'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e6'), 'LocationAbbr': 'ID', 'LocationDesc': 'Idaho', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '405'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e7'), 'LocationAbbr': 'IL', 'LocationDesc': 'Illinois', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2399'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e8'), 'LocationAbbr': 'IN', 'LocationDesc': 'Indiana', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1223'}
# {'_id': ObjectId('5e8827adcaeb91215177c1e9'), 'LocationAbbr': 'IA', 'LocationDesc': 'Iowa', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '798'}
# {'_id': ObjectId('5e8827adcaeb91215177c1ea'), 'LocationAbbr': 'KS', 'LocationDesc': 'Kansas', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '712'}
# {'_id': ObjectId('5e8827adcaeb91215177c1eb'), 'LocationAbbr': 'KY', 'LocationDesc': 'Kentucky', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1130'}
# {'_id': ObjectId('5e8827adcaeb91215177c1ec'), 'LocationAbbr': 'LA', 'LocationDesc': 'Louisiana', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '714'}
# {'_id': ObjectId('5e8827adcaeb91215177c1ed'), 'LocationAbbr': 'ME', 'LocationDesc': 'Maine', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '370'}
# {'_id': ObjectId('5e8827adcaeb91215177c1ee'), 'LocationAbbr': 'MD', 'LocationDesc': 'Maryland', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1272'}
# {'_id': ObjectId('5e8827adcaeb91215177c1ef'), 'LocationAbbr': 'MA', 'LocationDesc': 'Massachusetts', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1590'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f0'), 'LocationAbbr': 'MI', 'LocationDesc': 'Michigan', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2053'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f1'), 'LocationAbbr': 'MN', 'LocationDesc': 'Minnesota', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1530'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f2'), 'LocationAbbr': 'MS', 'LocationDesc': 'Mississippi', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '538'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f3'), 'LocationAbbr': 'MO', 'LocationDesc': 'Missouri', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1177'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f4'), 'LocationAbbr': 'MT', 'LocationDesc': 'Montana', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '268'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f5'), 'LocationAbbr': 'NE', 'LocationDesc': 'Nebraska', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '356'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f6'), 'LocationAbbr': 'NV', 'LocationDesc': 'Nevada', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': 0}
# {'_id': ObjectId('5e8827adcaeb91215177c1f7'), 'LocationAbbr': 'NH', 'LocationDesc': 'New Hampshire', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '400'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f8'), 'LocationAbbr': 'NJ', 'LocationDesc': 'New Jersey', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2093'}
# {'_id': ObjectId('5e8827adcaeb91215177c1f9'), 'LocationAbbr': 'NM', 'LocationDesc': 'New Mexico', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '406'}
# {'_id': ObjectId('5e8827adcaeb91215177c1fa'), 'LocationAbbr': 'NY', 'LocationDesc': 'New York', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '3717'}
# {'_id': ObjectId('5e8827adcaeb91215177c1fb'), 'LocationAbbr': 'NC', 'LocationDesc': 'North Carolina', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2302'}
# {'_id': ObjectId('5e8827adcaeb91215177c1fc'), 'LocationAbbr': 'ND', 'LocationDesc': 'North Dakota', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '158'}
# {'_id': ObjectId('5e8827adcaeb91215177c1fd'), 'LocationAbbr': 'OH', 'LocationDesc': 'Ohio', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '2491'}
# {'_id': ObjectId('5e8827adcaeb91215177c1fe'), 'LocationAbbr': 'OK', 'LocationDesc': 'Oklahoma', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '654'}
# {'_id': ObjectId('5e8827adcaeb91215177c1ff'), 'LocationAbbr': 'OR', 'LocationDesc': 'Oregon', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1140'}
# {'_id': ObjectId('5e8827adcaeb91215177c200'), 'LocationAbbr': 'PA', 'LocationDesc': 'Pennsylvania', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '3045'}
# {'_id': ObjectId('5e8827adcaeb91215177c201'), 'LocationAbbr': 'RI', 'LocationDesc': 'Rhode Island', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '252'}
# {'_id': ObjectId('5e8827adcaeb91215177c202'), 'LocationAbbr': 'SC', 'LocationDesc': 'South Carolina', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1144'}
# {'_id': ObjectId('5e8827adcaeb91215177c203'), 'LocationAbbr': 'SD', 'LocationDesc': 'South Dakota', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '167'}
# {'_id': ObjectId('5e8827adcaeb91215177c204'), 'LocationAbbr': 'TN', 'LocationDesc': 'Tennessee', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1431'}
# {'_id': ObjectId('5e8827adcaeb91215177c205'), 'LocationAbbr': 'TX', 'LocationDesc': 'Texas', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '3025'}
# {'_id': ObjectId('5e8827adcaeb91215177c206'), 'LocationAbbr': 'UT', 'LocationDesc': 'Utah', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '742'}
# {'_id': ObjectId('5e8827adcaeb91215177c207'), 'LocationAbbr': 'VT', 'LocationDesc': 'Vermont', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '215'}
# {'_id': ObjectId('5e8827adcaeb91215177c208'), 'LocationAbbr': 'VA', 'LocationDesc': 'Virginia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1535'}
# {'_id': ObjectId('5e8827adcaeb91215177c209'), 'LocationAbbr': 'WA', 'LocationDesc': 'Washington', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1821'}
# {'_id': ObjectId('5e8827adcaeb91215177c20a'), 'LocationAbbr': 'WV', 'LocationDesc': 'West Virginia', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '464'}
# {'_id': ObjectId('5e8827adcaeb91215177c20b'), 'LocationAbbr': 'WI', 'LocationDesc': 'Wisconsin', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '1284'}
# {'_id': ObjectId('5e8827adcaeb91215177c20c'), 'LocationAbbr': 'WY', 'LocationDesc': 'Wyoming', 'Topic': 'Cancer', 'Question': 'Invasive melanoma, incidence', 'DataValueType': 'Average Annual Number', 'DataValue': '135'}

# %% [markdown]
# #### 2. Melanoma Mortality Data

# %%
# Define database and collection
db = client.uv_melanoma_db
collection = db.melanoma_mortality

# %%
# Convert the data frame of melanoma mortality data to dictionary
mortality_dict = mortality_df.to_dict("records")
mortality_dict
# Out:
# [{'LocationAbbr': 'AL',
#   'LocationDesc': 'Alabama',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '151'},
#  {'LocationAbbr': 'AZ',
#   'LocationDesc': 'Arizona',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '203'},
#  {'LocationAbbr': 'AR',
#   'LocationDesc': 'Arkansas',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '93'},
#  {'LocationAbbr': 'CA',
#   'LocationDesc': 'California',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '943'},
#  {'LocationAbbr': 'CO',
#   'LocationDesc': 'Colorado',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '161'},
#  {'LocationAbbr': 'CT',
#   'LocationDesc': 'Connecticut',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '106'},
#  {'LocationAbbr': 'DE',
#   'LocationDesc': 'Delaware',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '29'},
#  {'LocationAbbr': 'DC',
#   'LocationDesc': 'District of Columbia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '7'},
#  {'LocationAbbr': 'FL',
#   'LocationDesc': 'Florida',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '728'},
#  {'LocationAbbr': 'GA',
#   'LocationDesc': 'Georgia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '217'},
#  {'LocationAbbr': 'ID',
#   'LocationDesc': 'Idaho',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '55'},
#  {'LocationAbbr': 'IL',
#   'LocationDesc': 'Illinois',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '328'},
#  {'LocationAbbr': 'IN',
#   'LocationDesc': 'Indiana',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '215'},
#  {'LocationAbbr': 'IA',
#   'LocationDesc': 'Iowa',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '106'},
#  {'LocationAbbr': 'KS',
#   'LocationDesc': 'Kansas',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '93'},
#  {'LocationAbbr': 'KY',
#   'LocationDesc': 'Kentucky',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '151'},
#  {'LocationAbbr': 'LA',
#   'LocationDesc': 'Louisiana',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '105'},
#  {'LocationAbbr': 'ME',
#   'LocationDesc': 'Maine',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '51'},
#  {'LocationAbbr': 'MD',
#   'LocationDesc': 'Maryland',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '160'},
#  {'LocationAbbr': 'MA',
#   'LocationDesc': 'Massachusetts',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '219'},
#  {'LocationAbbr': 'MI',
#   'LocationDesc': 'Michigan',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '275'},
#  {'LocationAbbr': 'MN',
#   'LocationDesc': 'Minnesota',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '144'},
#  {'LocationAbbr': 'MS',
#   'LocationDesc': 'Mississippi',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '71'},
#  {'LocationAbbr': 'MO',
#   'LocationDesc': 'Missouri',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '208'},
#  {'LocationAbbr': 'MT',
#   'LocationDesc': 'Montana',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '36'},
#  {'LocationAbbr': 'NE',
#   'LocationDesc': 'Nebraska',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '63'},
#  {'LocationAbbr': 'NV',
#   'LocationDesc': 'Nevada',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '80'},
#  {'LocationAbbr': 'NH',
#   'LocationDesc': 'New Hampshire',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '42'},
#  {'LocationAbbr': 'NJ',
#   'LocationDesc': 'New Jersey',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '245'},
#  {'LocationAbbr': 'NM',
#   'LocationDesc': 'New Mexico',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '60'},
#  {'LocationAbbr': 'NY',
#   'LocationDesc': 'New York',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '484'},
#  {'LocationAbbr': 'NC',
#   'LocationDesc': 'North Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '296'},
#  {'LocationAbbr': 'ND',
#   'LocationDesc': 'North Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '17'},
#  {'LocationAbbr': 'OH',
#   'LocationDesc': 'Ohio',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '391'},
#  {'LocationAbbr': 'OK',
#   'LocationDesc': 'Oklahoma',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '130'},
#  {'LocationAbbr': 'OR',
#   'LocationDesc': 'Oregon',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '147'},
#  {'LocationAbbr': 'PA',
#   'LocationDesc': 'Pennsylvania',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '459'},
#  {'LocationAbbr': 'RI',
#   'LocationDesc': 'Rhode Island',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '32'},
#  {'LocationAbbr': 'SC',
#   'LocationDesc': 'South Carolina',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '135'},
#  {'LocationAbbr': 'SD',
#   'LocationDesc': 'South Dakota',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '22'},
#  {'LocationAbbr': 'TN',
#   'LocationDesc': 'Tennessee',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '213'},
#  {'LocationAbbr': 'TX',
#   'LocationDesc': 'Texas',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '544'},
#  {'LocationAbbr': 'UT',
#   'LocationDesc': 'Utah',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '79'},
#  {'LocationAbbr': 'VT',
#   'LocationDesc': 'Vermont',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '23'},
#  {'LocationAbbr': 'VA',
#   'LocationDesc': 'Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '239'},
#  {'LocationAbbr': 'WA',
#   'LocationDesc': 'Washington',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '209'},
#  {'LocationAbbr': 'WV',
#   'LocationDesc': 'West Virginia',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '76'},
#  {'LocationAbbr': 'WI',
#   'LocationDesc': 'Wisconsin',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '176'},
#  {'LocationAbbr': 'WY',
#   'LocationDesc': 'Wyoming',
#   'Topic': 'Cancer',
#   'Question': 'Melanoma, mortality',
#   'DataValueType': 'Average Annual Number',
#   'DataValue': '18'}]

# %%
# Upload melanoma mortality data to MongoDB
for mortality_data in range(len(mortality_dict)):
    collection.insert_one(mortality_dict[mortality_data])

# %%
# Display the MongoDB records created above
melanoma_mortality_records = db.melanoma_mortality.find()
for melanoma_mortality_record in melanoma_mortality_records:
    print(melanoma_mortality_record)
# Out:
# {'_id': ObjectId('5e881d6adc733b52151f17be'), 'LocationDesc': 'Alabama', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '151'}
# {'_id': ObjectId('5e881d6adc733b52151f17bf'), 'LocationDesc': 'Arizona', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '203'}
# {'_id': ObjectId('5e881d6adc733b52151f17c0'), 'LocationDesc': 'Arkansas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '93'}
# {'_id': ObjectId('5e881d6adc733b52151f17c1'), 'LocationDesc': 'California', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '943'}
# {'_id': ObjectId('5e881d6adc733b52151f17c2'), 'LocationDesc': 'Colorado', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '161'}
# {'_id': ObjectId('5e881d6adc733b52151f17c3'), 'LocationDesc': 'Connecticut', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '106'}
# {'_id': ObjectId('5e881d6adc733b52151f17c4'), 'LocationDesc': 'Delaware', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '29'}
# {'_id': ObjectId('5e881d6adc733b52151f17c5'), 'LocationDesc': 'District of Columbia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '7'}
# {'_id': ObjectId('5e881d6adc733b52151f17c6'), 'LocationDesc': 'Florida', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '728'}
# {'_id': ObjectId('5e881d6adc733b52151f17c7'), 'LocationDesc': 'Georgia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '217'}
# {'_id': ObjectId('5e881d6adc733b52151f17c8'), 'LocationDesc': 'Idaho', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '55'}
# {'_id': ObjectId('5e881d6adc733b52151f17c9'), 'LocationDesc': 'Illinois', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '328'}
# {'_id': ObjectId('5e881d6adc733b52151f17ca'), 'LocationDesc': 'Indiana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '215'}
# {'_id': ObjectId('5e881d6adc733b52151f17cb'), 'LocationDesc': 'Iowa', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '106'}
# {'_id': ObjectId('5e881d6adc733b52151f17cc'), 'LocationDesc': 'Kansas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '93'}
# {'_id': ObjectId('5e881d6adc733b52151f17cd'), 'LocationDesc': 'Kentucky', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '151'}
# {'_id': ObjectId('5e881d6adc733b52151f17ce'), 'LocationDesc': 'Louisiana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '105'}
# {'_id': ObjectId('5e881d6adc733b52151f17cf'), 'LocationDesc': 'Maine', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '51'}
# {'_id': ObjectId('5e881d6adc733b52151f17d0'), 'LocationDesc': 'Maryland', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '160'}
# {'_id': ObjectId('5e881d6adc733b52151f17d1'), 'LocationDesc': 'Massachusetts', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '219'}
# {'_id': ObjectId('5e881d6adc733b52151f17d2'), 'LocationDesc': 'Michigan', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '275'}
# {'_id': ObjectId('5e881d6adc733b52151f17d3'), 'LocationDesc': 'Minnesota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '144'}
# {'_id': ObjectId('5e881d6adc733b52151f17d4'), 'LocationDesc': 'Mississippi', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '71'}
# {'_id': ObjectId('5e881d6adc733b52151f17d5'), 'LocationDesc': 'Missouri', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '208'}
# {'_id': ObjectId('5e881d6adc733b52151f17d6'), 'LocationDesc': 'Montana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '36'}
# {'_id': ObjectId('5e881d6adc733b52151f17d7'), 'LocationDesc': 'Nebraska', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '63'}
# {'_id': ObjectId('5e881d6adc733b52151f17d8'), 'LocationDesc': 'Nevada', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '80'}
# {'_id': ObjectId('5e881d6adc733b52151f17d9'), 'LocationDesc': 'New Hampshire', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '42'}
# {'_id': ObjectId('5e881d6adc733b52151f17da'), 'LocationDesc': 'New Jersey', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '245'}
# {'_id': ObjectId('5e881d6adc733b52151f17db'), 'LocationDesc': 'New Mexico', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '60'}
# {'_id': ObjectId('5e881d6adc733b52151f17dc'), 'LocationDesc': 'New York', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '484'}
# {'_id': ObjectId('5e881d6adc733b52151f17dd'), 'LocationDesc': 'North Carolina', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '296'}
# {'_id': ObjectId('5e881d6adc733b52151f17de'), 'LocationDesc': 'North Dakota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '17'}
# {'_id': ObjectId('5e881d6adc733b52151f17df'), 'LocationDesc': 'Ohio', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '391'}
# {'_id': ObjectId('5e881d6adc733b52151f17e0'), 'LocationDesc': 'Oklahoma', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '130'}
# {'_id': ObjectId('5e881d6adc733b52151f17e1'), 'LocationDesc': 'Oregon', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '147'}
# {'_id': ObjectId('5e881d6adc733b52151f17e2'), 'LocationDesc': 'Pennsylvania', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '459'}
# {'_id': ObjectId('5e881d6adc733b52151f17e3'), 'LocationDesc': 'Rhode Island', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '32'}
# {'_id': ObjectId('5e881d6adc733b52151f17e4'), 'LocationDesc': 'South Carolina', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '135'}
# {'_id': ObjectId('5e881d6adc733b52151f17e5'), 'LocationDesc': 'South Dakota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '22'}
# {'_id': ObjectId('5e881d6adc733b52151f17e6'), 'LocationDesc': 'Tennessee', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '213'}
# {'_id': ObjectId('5e881d6adc733b52151f17e7'), 'LocationDesc': 'Texas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '544'}
# {'_id': ObjectId('5e881d6adc733b52151f17e8'), 'LocationDesc': 'Utah', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '79'}
# {'_id': ObjectId('5e881d6adc733b52151f17e9'), 'LocationDesc': 'Vermont', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '23'}
# {'_id': ObjectId('5e881d6adc733b52151f17ea'), 'LocationDesc': 'Virginia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '239'}
# {'_id': ObjectId('5e881d6adc733b52151f17eb'), 'LocationDesc': 'Washington', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '209'}
# {'_id': ObjectId('5e881d6adc733b52151f17ec'), 'LocationDesc': 'West Virginia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '76'}
# {'_id': ObjectId('5e881d6adc733b52151f17ed'), 'LocationDesc': 'Wisconsin', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '176'}
# {'_id': ObjectId('5e881d6adc733b52151f17ee'), 'LocationDesc': 'Wyoming', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '18'}
# {'_id': ObjectId('5e8823d4caeb91215177c115'), 'LocationAbbr': 'AL', 'LocationDesc': 'Alabama', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '151'}
# {'_id': ObjectId('5e8823d4caeb91215177c116'), 'LocationAbbr': 'AZ', 'LocationDesc': 'Arizona', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '203'}
# {'_id': ObjectId('5e8823d4caeb91215177c117'), 'LocationAbbr': 'AR', 'LocationDesc': 'Arkansas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '93'}
# {'_id': ObjectId('5e8823d4caeb91215177c118'), 'LocationAbbr': 'CA', 'LocationDesc': 'California', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '943'}
# {'_id': ObjectId('5e8823d4caeb91215177c119'), 'LocationAbbr': 'CO', 'LocationDesc': 'Colorado', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '161'}
# {'_id': ObjectId('5e8823d4caeb91215177c11a'), 'LocationAbbr': 'CT', 'LocationDesc': 'Connecticut', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '106'}
# {'_id': ObjectId('5e8823d4caeb91215177c11b'), 'LocationAbbr': 'DE', 'LocationDesc': 'Delaware', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '29'}
# {'_id': ObjectId('5e8823d4caeb91215177c11c'), 'LocationAbbr': 'DC', 'LocationDesc': 'District of Columbia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '7'}
# {'_id': ObjectId('5e8823d4caeb91215177c11d'), 'LocationAbbr': 'FL', 'LocationDesc': 'Florida', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '728'}
# {'_id': ObjectId('5e8823d4caeb91215177c11e'), 'LocationAbbr': 'GA', 'LocationDesc': 'Georgia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '217'}
# {'_id': ObjectId('5e8823d4caeb91215177c11f'), 'LocationAbbr': 'ID', 'LocationDesc': 'Idaho', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '55'}
# {'_id': ObjectId('5e8823d4caeb91215177c120'), 'LocationAbbr': 'IL', 'LocationDesc': 'Illinois', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '328'}
# {'_id': ObjectId('5e8823d4caeb91215177c121'), 'LocationAbbr': 'IN', 'LocationDesc': 'Indiana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '215'}
# {'_id': ObjectId('5e8823d4caeb91215177c122'), 'LocationAbbr': 'IA', 'LocationDesc': 'Iowa', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '106'}
# {'_id': ObjectId('5e8823d4caeb91215177c123'), 'LocationAbbr': 'KS', 'LocationDesc': 'Kansas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '93'}
# {'_id': ObjectId('5e8823d4caeb91215177c124'), 'LocationAbbr': 'KY', 'LocationDesc': 'Kentucky', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '151'}
# {'_id': ObjectId('5e8823d4caeb91215177c125'), 'LocationAbbr': 'LA', 'LocationDesc': 'Louisiana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '105'}
# {'_id': ObjectId('5e8823d4caeb91215177c126'), 'LocationAbbr': 'ME', 'LocationDesc': 'Maine', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '51'}
# {'_id': ObjectId('5e8823d4caeb91215177c127'), 'LocationAbbr': 'MD', 'LocationDesc': 'Maryland', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '160'}
# {'_id': ObjectId('5e8823d4caeb91215177c128'), 'LocationAbbr': 'MA', 'LocationDesc': 'Massachusetts', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '219'}
# {'_id': ObjectId('5e8823d4caeb91215177c129'), 'LocationAbbr': 'MI', 'LocationDesc': 'Michigan', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '275'}
# {'_id': ObjectId('5e8823d4caeb91215177c12a'), 'LocationAbbr': 'MN', 'LocationDesc': 'Minnesota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '144'}
# {'_id': ObjectId('5e8823d4caeb91215177c12b'), 'LocationAbbr': 'MS', 'LocationDesc': 'Mississippi', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '71'}
# {'_id': ObjectId('5e8823d4caeb91215177c12c'), 'LocationAbbr': 'MO', 'LocationDesc': 'Missouri', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '208'}
# {'_id': ObjectId('5e8823d4caeb91215177c12d'), 'LocationAbbr': 'MT', 'LocationDesc': 'Montana', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '36'}
# {'_id': ObjectId('5e8823d4caeb91215177c12e'), 'LocationAbbr': 'NE', 'LocationDesc': 'Nebraska', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '63'}
# {'_id': ObjectId('5e8823d4caeb91215177c12f'), 'LocationAbbr': 'NV', 'LocationDesc': 'Nevada', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '80'}
# {'_id': ObjectId('5e8823d4caeb91215177c130'), 'LocationAbbr': 'NH', 'LocationDesc': 'New Hampshire', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '42'}
# {'_id': ObjectId('5e8823d4caeb91215177c131'), 'LocationAbbr': 'NJ', 'LocationDesc': 'New Jersey', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '245'}
# {'_id': ObjectId('5e8823d4caeb91215177c132'), 'LocationAbbr': 'NM', 'LocationDesc': 'New Mexico', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '60'}
# {'_id': ObjectId('5e8823d4caeb91215177c133'), 'LocationAbbr': 'NY', 'LocationDesc': 'New York', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '484'}
# {'_id': ObjectId('5e8823d4caeb91215177c134'), 'LocationAbbr': 'NC', 'LocationDesc': 'North Carolina', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '296'}
# {'_id': ObjectId('5e8823d4caeb91215177c135'), 'LocationAbbr': 'ND', 'LocationDesc': 'North Dakota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '17'}
# {'_id': ObjectId('5e8823d4caeb91215177c136'), 'LocationAbbr': 'OH', 'LocationDesc': 'Ohio', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '391'}
# {'_id': ObjectId('5e8823d4caeb91215177c137'), 'LocationAbbr': 'OK', 'LocationDesc': 'Oklahoma', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '130'}
# {'_id': ObjectId('5e8823d4caeb91215177c138'), 'LocationAbbr': 'OR', 'LocationDesc': 'Oregon', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '147'}
# {'_id': ObjectId('5e8823d4caeb91215177c139'), 'LocationAbbr': 'PA', 'LocationDesc': 'Pennsylvania', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '459'}
# {'_id': ObjectId('5e8823d4caeb91215177c13a'), 'LocationAbbr': 'RI', 'LocationDesc': 'Rhode Island', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '32'}
# {'_id': ObjectId('5e8823d4caeb91215177c13b'), 'LocationAbbr': 'SC', 'LocationDesc': 'South Carolina', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '135'}
# {'_id': ObjectId('5e8823d4caeb91215177c13c'), 'LocationAbbr': 'SD', 'LocationDesc': 'South Dakota', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '22'}
# {'_id': ObjectId('5e8823d4caeb91215177c13d'), 'LocationAbbr': 'TN', 'LocationDesc': 'Tennessee', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '213'}
# {'_id': ObjectId('5e8823d4caeb91215177c13e'), 'LocationAbbr': 'TX', 'LocationDesc': 'Texas', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '544'}
# {'_id': ObjectId('5e8823d4caeb91215177c13f'), 'LocationAbbr': 'UT', 'LocationDesc': 'Utah', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '79'}
# {'_id': ObjectId('5e8823d4caeb91215177c140'), 'LocationAbbr': 'VT', 'LocationDesc': 'Vermont', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '23'}
# {'_id': ObjectId('5e8823d4caeb91215177c141'), 'LocationAbbr': 'VA', 'LocationDesc': 'Virginia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '239'}
# {'_id': ObjectId('5e8823d4caeb91215177c142'), 'LocationAbbr': 'WA', 'LocationDesc': 'Washington', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '209'}
# {'_id': ObjectId('5e8823d4caeb91215177c143'), 'LocationAbbr': 'WV', 'LocationDesc': 'West Virginia', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '76'}
# {'_id': ObjectId('5e8823d4caeb91215177c144'), 'LocationAbbr': 'WI', 'LocationDesc': 'Wisconsin', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '176'}
# {'_id': ObjectId('5e8823d4caeb91215177c145'), 'LocationAbbr': 'WY', 'LocationDesc': 'Wyoming', 'Topic': 'Cancer', 'Question': 'Melanoma, mortality', 'DataValueType': 'Average Annual Number', 'DataValue': '18'}

# %% [markdown]
# #### 3. UV Exposure Data

# %%
# Define database and collection
db = client.uv_melanoma_db
collection = db.uv

# %%
# Convert the data frame of UV exposure data to dictionary
UV_dict = UV_data_df.to_dict("records")
UV_dict
# Out:
# [{'UV_Wh/square_meter': 4505.164179104478},
#  {'UV_Wh/square_meter': 5528.466666666666},
#  {'UV_Wh/square_meter': 4515.346666666666},
#  {'UV_Wh/square_meter': 4871.413793103448},
#  {'UV_Wh/square_meter': 4802.730158730159},
#  {'UV_Wh/square_meter': 3832.5},
#  {'UV_Wh/square_meter': 4074.0},
#  {'UV_Wh/square_meter': 4100.0},
#  {'UV_Wh/square_meter': 4743.671641791045},
#  {'UV_Wh/square_meter': 4563.974842767296},
#  {'UV_Wh/square_meter': 4170.545454545455},
#  {'UV_Wh/square_meter': 4117.4607843137255},
#  {'UV_Wh/square_meter': 4019.3804347826085},
#  {'UV_Wh/square_meter': 4053.5454545454545},
#  {'UV_Wh/square_meter': 4572.047619047619},
#  {'UV_Wh/square_meter': 4113.825},
#  {'UV_Wh/square_meter': 4557.875},
#  {'UV_Wh/square_meter': 3779.375},
#  {'UV_Wh/square_meter': 4057.1666666666665},
#  {'UV_Wh/square_meter': 3874.785714285714},
#  {'UV_Wh/square_meter': 3715.867469879518},
#  {'UV_Wh/square_meter': 3841.022988505747},
#  {'UV_Wh/square_meter': 4518.817073170731},
#  {'UV_Wh/square_meter': 4308.339130434782},
#  {'UV_Wh/square_meter': 3927.964285714286},
#  {'UV_Wh/square_meter': 4350.763440860215},
#  {'UV_Wh/square_meter': 4977.0},
#  {'UV_Wh/square_meter': 3841.5},
#  {'UV_Wh/square_meter': 3951.095238095238},
#  {'UV_Wh/square_meter': 5439.69696969697},
#  {'UV_Wh/square_meter': 3745.1290322580644},
#  {'UV_Wh/square_meter': 4352.17},
#  {'UV_Wh/square_meter': 3902.1132075471696},
#  {'UV_Wh/square_meter': 3842.056818181818},
#  {'UV_Wh/square_meter': 4714.7532467532465},
#  {'UV_Wh/square_meter': 3977.777777777778},
#  {'UV_Wh/square_meter': 3809.208955223881},
#  {'UV_Wh/square_meter': 3881.4},
#  {'UV_Wh/square_meter': 4525.021739130435},
#  {'UV_Wh/square_meter': 4111.742424242424},
#  {'UV_Wh/square_meter': 4278.578947368421},
#  {'UV_Wh/square_meter': 4917.952755905511},
#  {'UV_Wh/square_meter': 4737.551724137931},
#  {'UV_Wh/square_meter': 3744.0714285714284},
#  {'UV_Wh/square_meter': 4181.985074626866},
#  {'UV_Wh/square_meter': 3594.102564102564},
#  {'UV_Wh/square_meter': 3892.3636363636365},
#  {'UV_Wh/square_meter': 3810.7083333333335},
#  {'UV_Wh/square_meter': 4350.521739130435}]

# %%
# Upload UV exposure data to MongoDB
for UV_data in range(len(UV_dict)):
    collection.insert_one(UV_dict[UV_data])

# %%
# Display the MongoDB records created above
UV_records = db.uv.find()
for UV_record in UV_records:
    print(UV_record)
# Out:
# {'_id': ObjectId('5e881d6adc733b52151f17ef'), 'STATENAME': 'Alabama', 'UV_Wh/square_meter': 4505.164179104478}
# {'_id': ObjectId('5e881d6adc733b52151f17f0'), 'STATENAME': 'Arizona', 'UV_Wh/square_meter': 5528.466666666666}
# {'_id': ObjectId('5e881d6adc733b52151f17f1'), 'STATENAME': 'Arkansas', 'UV_Wh/square_meter': 4515.346666666666}
# {'_id': ObjectId('5e881d6adc733b52151f17f2'), 'STATENAME': 'California', 'UV_Wh/square_meter': 4871.413793103448}
# {'_id': ObjectId('5e881d6adc733b52151f17f3'), 'STATENAME': 'Colorado', 'UV_Wh/square_meter': 4802.730158730159}
# {'_id': ObjectId('5e881d6adc733b52151f17f4'), 'STATENAME': 'Connecticut', 'UV_Wh/square_meter': 3832.5}
# {'_id': ObjectId('5e881d6adc733b52151f17f5'), 'STATENAME': 'Delaware', 'UV_Wh/square_meter': 4074.0}
# {'_id': ObjectId('5e881d6adc733b52151f17f6'), 'STATENAME': 'District of Columbia', 'UV_Wh/square_meter': 4100.0}
# {'_id': ObjectId('5e881d6adc733b52151f17f7'), 'STATENAME': 'Florida', 'UV_Wh/square_meter': 4743.671641791045}
# {'_id': ObjectId('5e881d6adc733b52151f17f8'), 'STATENAME': 'Georgia', 'UV_Wh/square_meter': 4563.974842767296}
# {'_id': ObjectId('5e881d6adc733b52151f17f9'), 'STATENAME': 'Idaho', 'UV_Wh/square_meter': 4170.545454545455}
# {'_id': ObjectId('5e881d6adc733b52151f17fa'), 'STATENAME': 'Illinois', 'UV_Wh/square_meter': 4117.4607843137255}
# {'_id': ObjectId('5e881d6adc733b52151f17fb'), 'STATENAME': 'Indiana', 'UV_Wh/square_meter': 4019.3804347826085}
# {'_id': ObjectId('5e881d6adc733b52151f17fc'), 'STATENAME': 'Iowa', 'UV_Wh/square_meter': 4053.5454545454545}
# {'_id': ObjectId('5e881d6adc733b52151f17fd'), 'STATENAME': 'Kansas', 'UV_Wh/square_meter': 4572.047619047619}
# {'_id': ObjectId('5e881d6adc733b52151f17fe'), 'STATENAME': 'Kentucky', 'UV_Wh/square_meter': 4113.825}
# {'_id': ObjectId('5e881d6adc733b52151f17ff'), 'STATENAME': 'Louisiana', 'UV_Wh/square_meter': 4557.875}
# {'_id': ObjectId('5e881d6adc733b52151f1800'), 'STATENAME': 'Maine', 'UV_Wh/square_meter': 3779.375}
# {'_id': ObjectId('5e881d6adc733b52151f1801'), 'STATENAME': 'Maryland', 'UV_Wh/square_meter': 4057.1666666666665}
# {'_id': ObjectId('5e881d6adc733b52151f1802'), 'STATENAME': 'Massachusetts', 'UV_Wh/square_meter': 3874.785714285714}
# {'_id': ObjectId('5e881d6adc733b52151f1803'), 'STATENAME': 'Michigan', 'UV_Wh/square_meter': 3715.867469879518}
# {'_id': ObjectId('5e881d6adc733b52151f1804'), 'STATENAME': 'Minnesota', 'UV_Wh/square_meter': 3841.022988505747}
# {'_id': ObjectId('5e881d6adc733b52151f1805'), 'STATENAME': 'Mississippi', 'UV_Wh/square_meter': 4518.817073170731}
# {'_id': ObjectId('5e881d6adc733b52151f1806'), 'STATENAME': 'Missouri', 'UV_Wh/square_meter': 4308.339130434782}
# {'_id': ObjectId('5e881d6adc733b52151f1807'), 'STATENAME': 'Montana', 'UV_Wh/square_meter': 3927.964285714286}
# {'_id': ObjectId('5e881d6adc733b52151f1808'), 'STATENAME': 'Nebraska', 'UV_Wh/square_meter': 4350.763440860215}
# {'_id': ObjectId('5e881d6adc733b52151f1809'), 'STATENAME': 'Nevada', 'UV_Wh/square_meter': 4977.0}
# {'_id': ObjectId('5e881d6adc733b52151f180a'), 'STATENAME': 'New Hampshire', 'UV_Wh/square_meter': 3841.5}
# {'_id': ObjectId('5e881d6adc733b52151f180b'), 'STATENAME': 'New Jersey', 'UV_Wh/square_meter': 3951.095238095238}
# {'_id': ObjectId('5e881d6adc733b52151f180c'), 'STATENAME': 'New Mexico', 'UV_Wh/square_meter': 5439.69696969697}
# {'_id': ObjectId('5e881d6adc733b52151f180d'), 'STATENAME': 'New York', 'UV_Wh/square_meter': 3745.1290322580644}
# {'_id': ObjectId('5e881d6adc733b52151f180e'), 'STATENAME': 'North Carolina', 'UV_Wh/square_meter': 4352.17}
# {'_id': ObjectId('5e881d6adc733b52151f180f'), 'STATENAME': 'North Dakota', 'UV_Wh/square_meter': 3902.1132075471696}
# {'_id': ObjectId('5e881d6adc733b52151f1810'), 'STATENAME': 'Ohio', 'UV_Wh/square_meter': 3842.056818181818}
# {'_id': ObjectId('5e881d6adc733b52151f1811'), 'STATENAME': 'Oklahoma', 'UV_Wh/square_meter': 4714.7532467532465}
# {'_id': ObjectId('5e881d6adc733b52151f1812'), 'STATENAME': 'Oregon', 'UV_Wh/square_meter': 3977.777777777778}
# {'_id': ObjectId('5e881d6adc733b52151f1813'), 'STATENAME': 'Pennsylvania', 'UV_Wh/square_meter': 3809.208955223881}
# {'_id': ObjectId('5e881d6adc733b52151f1814'), 'STATENAME': 'Rhode Island', 'UV_Wh/square_meter': 3881.4}
# {'_id': ObjectId('5e881d6adc733b52151f1815'), 'STATENAME': 'South Carolina', 'UV_Wh/square_meter': 4525.021739130435}
# {'_id': ObjectId('5e881d6adc733b52151f1816'), 'STATENAME': 'South Dakota', 'UV_Wh/square_meter': 4111.742424242424}
# {'_id': ObjectId('5e881d6adc733b52151f1817'), 'STATENAME': 'Tennessee', 'UV_Wh/square_meter': 4278.578947368421}
# {'_id': ObjectId('5e881d6adc733b52151f1818'), 'STATENAME': 'Texas', 'UV_Wh/square_meter': 4917.952755905511}
# {'_id': ObjectId('5e881d6adc733b52151f1819'), 'STATENAME': 'Utah', 'UV_Wh/square_meter': 4737.551724137931}
# {'_id': ObjectId('5e881d6adc733b52151f181a'), 'STATENAME': 'Vermont', 'UV_Wh/square_meter': 3744.0714285714284}
# {'_id': ObjectId('5e881d6adc733b52151f181b'), 'STATENAME': 'Virginia', 'UV_Wh/square_meter': 4181.985074626866}
# {'_id': ObjectId('5e881d6adc733b52151f181c'), 'STATENAME': 'Washington', 'UV_Wh/square_meter': 3594.102564102564}
# {'_id': ObjectId('5e881d6adc733b52151f181d'), 'STATENAME': 'West Virginia', 'UV_Wh/square_meter': 3892.3636363636365}
# {'_id': ObjectId('5e881d6adc733b52151f181e'), 'STATENAME': 'Wisconsin', 'UV_Wh/square_meter': 3810.7083333333335}
# {'_id': ObjectId('5e881d6adc733b52151f181f'), 'STATENAME': 'Wyoming', 'UV_Wh/square_meter': 4350.521739130435}
# {'_id': ObjectId('5e881f35caeb91215177c0b2'), 'UV_Wh/square_meter': 4505.164179104478}
# {'_id': ObjectId('5e881f35caeb91215177c0b3'), 'UV_Wh/square_meter': 5528.466666666666}
# {'_id': ObjectId('5e881f35caeb91215177c0b4'), 'UV_Wh/square_meter': 4515.346666666666}
# {'_id': ObjectId('5e881f35caeb91215177c0b5'), 'UV_Wh/square_meter': 4871.413793103448}
# {'_id': ObjectId('5e881f35caeb91215177c0b6'), 'UV_Wh/square_meter': 4802.730158730159}
# {'_id': ObjectId('5e881f35caeb91215177c0b7'), 'UV_Wh/square_meter': 3832.5}
# {'_id': ObjectId('5e881f35caeb91215177c0b8'), 'UV_Wh/square_meter': 4074.0}
# {'_id': ObjectId('5e881f35caeb91215177c0b9'), 'UV_Wh/square_meter': 4100.0}
# {'_id': ObjectId('5e881f35caeb91215177c0ba'), 'UV_Wh/square_meter': 4743.671641791045}
# {'_id': ObjectId('5e881f35caeb91215177c0bb'), 'UV_Wh/square_meter': 4563.974842767296}
# {'_id': ObjectId('5e881f35caeb91215177c0bc'), 'UV_Wh/square_meter': 4170.545454545455}
# {'_id': ObjectId('5e881f35caeb91215177c0bd'), 'UV_Wh/square_meter': 4117.4607843137255}
# {'_id': ObjectId('5e881f35caeb91215177c0be'), 'UV_Wh/square_meter': 4019.3804347826085}
# {'_id': ObjectId('5e881f35caeb91215177c0bf'), 'UV_Wh/square_meter': 4053.5454545454545}
# {'_id': ObjectId('5e881f35caeb91215177c0c0'), 'UV_Wh/square_meter': 4572.047619047619}
# {'_id': ObjectId('5e881f35caeb91215177c0c1'), 'UV_Wh/square_meter': 4113.825}
# {'_id': ObjectId('5e881f35caeb91215177c0c2'), 'UV_Wh/square_meter': 4557.875}
# {'_id': ObjectId('5e881f35caeb91215177c0c3'), 'UV_Wh/square_meter': 3779.375}
# {'_id': ObjectId('5e881f35caeb91215177c0c4'), 'UV_Wh/square_meter': 4057.1666666666665}
# {'_id': ObjectId('5e881f35caeb91215177c0c5'), 'UV_Wh/square_meter': 3874.785714285714}
# {'_id': ObjectId('5e881f35caeb91215177c0c6'), 'UV_Wh/square_meter': 3715.867469879518}
# {'_id': ObjectId('5e881f35caeb91215177c0c7'), 'UV_Wh/square_meter': 3841.022988505747}
# {'_id': ObjectId('5e881f35caeb91215177c0c8'), 'UV_Wh/square_meter': 4518.817073170731}
# {'_id': ObjectId('5e881f35caeb91215177c0c9'), 'UV_Wh/square_meter': 4308.339130434782}
# {'_id': ObjectId('5e881f35caeb91215177c0ca'), 'UV_Wh/square_meter': 3927.964285714286}
# {'_id': ObjectId('5e881f35caeb91215177c0cb'), 'UV_Wh/square_meter': 4350.763440860215}
# {'_id': ObjectId('5e881f35caeb91215177c0cc'), 'UV_Wh/square_meter': 4977.0}
# {'_id': ObjectId('5e881f35caeb91215177c0cd'), 'UV_Wh/square_meter': 3841.5}
# {'_id': ObjectId('5e881f35caeb91215177c0ce'), 'UV_Wh/square_meter': 3951.095238095238}
# {'_id': ObjectId('5e881f35caeb91215177c0cf'), 'UV_Wh/square_meter': 5439.69696969697}
# {'_id': ObjectId('5e881f35caeb91215177c0d0'), 'UV_Wh/square_meter': 3745.1290322580644}
# {'_id': ObjectId('5e881f35caeb91215177c0d1'), 'UV_Wh/square_meter': 4352.17}
# {'_id': ObjectId('5e881f35caeb91215177c0d2'), 'UV_Wh/square_meter': 3902.1132075471696}
# {'_id': ObjectId('5e881f35caeb91215177c0d3'), 'UV_Wh/square_meter': 3842.056818181818}
# {'_id': ObjectId('5e881f35caeb91215177c0d4'), 'UV_Wh/square_meter': 4714.7532467532465}
# {'_id': ObjectId('5e881f35caeb91215177c0d5'), 'UV_Wh/square_meter': 3977.777777777778}
# {'_id': ObjectId('5e881f35caeb91215177c0d6'), 'UV_Wh/square_meter': 3809.208955223881}
# {'_id': ObjectId('5e881f35caeb91215177c0d7'), 'UV_Wh/square_meter': 3881.4}
# {'_id': ObjectId('5e881f35caeb91215177c0d8'), 'UV_Wh/square_meter': 4525.021739130435}
# {'_id': ObjectId('5e881f35caeb91215177c0d9'), 'UV_Wh/square_meter': 4111.742424242424}
# {'_id': ObjectId('5e881f35caeb91215177c0da'), 'UV_Wh/square_meter': 4278.578947368421}
# {'_id': ObjectId('5e881f35caeb91215177c0db'), 'UV_Wh/square_meter': 4917.952755905511}
# {'_id': ObjectId('5e881f35caeb91215177c0dc'), 'UV_Wh/square_meter': 4737.551724137931}
# {'_id': ObjectId('5e881f35caeb91215177c0dd'), 'UV_Wh/square_meter': 3744.0714285714284}
# {'_id': ObjectId('5e881f35caeb91215177c0de'), 'UV_Wh/square_meter': 4181.985074626866}
# {'_id': ObjectId('5e881f35caeb91215177c0df'), 'UV_Wh/square_meter': 3594.102564102564}
# {'_id': ObjectId('5e881f35caeb91215177c0e0'), 'UV_Wh/square_meter': 3892.3636363636365}
# {'_id': ObjectId('5e881f35caeb91215177c0e1'), 'UV_Wh/square_meter': 3810.7083333333335}
# {'_id': ObjectId('5e881f35caeb91215177c0e2'), 'UV_Wh/square_meter': 4350.521739130435}

# %% [markdown]
# PLAN:
# - Dropdown for each states
# - Map showing the UV exposure and layers for incidence and mortality

# %%
# CLEANING WITH PANDAS - DONE
# MONGODB - DONE
# FLASK APP
# VISUALIZATIONS (JS)
# WEB DEPLOYMENT

# %%
# %load_ext sql

# %%
DB_ENDPOINT = "localhost"
DB = 'melanoma_db'
DB_USER = 'postgres'
DB_PASSWORD = [REDACTED]
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)

# %%
# %sql $conn_string
# Out:
# 'Connected: postgres@melanoma_db'

# %%
rds_connection_string = "postgres:password@localhost:5432/melanoma_db"

engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['incidence', 'mortality', 'uv']

# %%
pd.read_sql_query('select * from uv', con=engine)
# Out:
#                statename           uv
# 0                Alabama  4505.164179
# 1                Arizona  5528.466667
# 2               Arkansas  4515.346667
# 3             California  4871.413793
# 4               Colorado  4802.730159
# 5            Connecticut  3832.500000
# 6               Delaware  4074.000000
# 7   District of Columbia  4100.000000
# 8                Florida  4743.671642
# 9                Georgia  4563.974843
# 10                 Idaho  4170.545455
# 11              Illinois  4117.460784
# 12               Indiana  4019.380435
# 13                  Iowa  4053.545455
# 14                Kansas  4572.047619
# 15              Kentucky  4113.825000
# 16             Louisiana  4557.875000
# 17                 Maine  3779.375000
# 18              Maryland  4057.166667
# 19         Massachusetts  3874.785714
# 20              Michigan  3715.867470
# 21             Minnesota  3841.022989
# 22           Mississippi  4518.817073
# 23              Missouri  4308.339130
# 24               Montana  3927.964286
# 25              Nebraska  4350.763441
# 26                Nevada  4977.000000
# 27         New Hampshire  3841.500000
# 28            New Jersey  3951.095238
# 29            New Mexico  5439.696970
# 30              New York  3745.129032
# 31        North Carolina  4352.170000
# 32          North Dakota  3902.113208
# 33                  Ohio  3842.056818
# 34              Oklahoma  4714.753247
# 35                Oregon  3977.777778
# 36          Pennsylvania  3809.208955
# 37          Rhode Island  3881.400000
# 38        South Carolina  4525.021739
# 39          South Dakota  4111.742424
# 40             Tennessee  4278.578947
# 41                 Texas  4917.952756
# 42                  Utah  4737.551724
# 43               Vermont  3744.071429
# 44              Virginia  4181.985075
# 45            Washington  3594.102564
# 46         West Virginia  3892.363636
# 47             Wisconsin  3810.708333
# 48               Wyoming  4350.521739
